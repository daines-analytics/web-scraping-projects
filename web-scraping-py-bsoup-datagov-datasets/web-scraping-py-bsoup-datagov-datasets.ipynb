# %% [markdown]
# # Web Scraping of Data.gov Dataset Catalog Using Python and BeautifulSoup
# ### David Lowe
# ### January 31, 2020
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific pieces of information from a website. The Python web scraping code leverages the Beautiful module.
#
# INTRODUCTION: Data.gov is a government data repository website managed and hosted by the U.S. General Services Administration. The purpose of this exercise is to practice web scraping by gathering the dataset entries from Data.gov’s web pages. This iteration of the script automatically traverses the web pages to capture all dataset entries and store all captured information in a JSON output file.
#
# Starting URLs: https://catalog.data.gov/dataset

# %% [markdown]
# ## Section 1. Prepare Environment

# %%
import os
import shutil
import smtplib
import sys
import pandas as pd
from email.message import EmailMessage
from datetime import datetime
from random import randint
from time import sleep
import requests
from requests.exceptions import HTTPError
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
# from selenium import webdriver
# from selenium.webdriver.firefox.options import Options

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose and debug flags to print detailed messages for debugging (setting True will activate!)
verbose = False
debug = False

# Set up the flag to send status emails (setting to True will send the status emails!)
notifyStatus = True

# Set up the flag to write the output to a JSON document (setting to TRUE will create the document!)
writeToJSON = True

# Set up the mountStorage flag to mount G Drive for storing files (setting True will mount the drive!)
mountStorage = False

# Set up the executeDownload flag to download files (setting True will download!)
executeDownload = False

# %%
# Colab-Specific Setup - Mount Google Drive for storing downloaded files
if (mountStorage):
    from google.colab import drive
    drive.mount('/content/gdrive')

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Web Scraping Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
def access_url_bsoup(url):
    # Creating an html document from the URL
    uastring = "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0"
    headers={'User-Agent': uastring}
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(3,6)
    print("Waiting " + str(waitTime) + " seconds to finish retrieving the URL.")
    sleep(waitTime)
    print('Attempting to access the web page: ' + url)
    try:
        s = requests.Session()
        resp = s.get(url, headers=headers)
        if (debug): print(resp.text)
    except HTTPError as e:
        print('The server could not serve up the web page!')
        sys.exit("Script processing cannot continue!!!")
    except ConnectionError as e:
        print('The server could not be reached due to connection issues!')
        sys.exit("Script processing cannot continue!!!")

    if (resp.status_code==requests.codes.ok):
        print('Successfully accessed the web page: ' + url)
        bsoup_obj = BeautifulSoup(resp.text, 'lxml')
        return(bsoup_obj)

# %%
def access_url_sel(url):
    wait_time = 5
    firefox_options = Options()
    firefox_options.headless = True
    print('Attempting to access the web page: ' + url)
    browser = webdriver.Firefox(options=firefox_options)
    browser.get(url)
    print("Waiting " + str(waitTime) + " seconds to finish retrieving the URL.")
    sleep(wait_time)
    innerHTML = browser.execute_script("return document.body.innerHTML")
    sleep(wait_time)
    bsoup_obj = BeautifulSoup(innerHTML, 'lxml')
    if (debug): print(bsoup_obj.prettify())
    browser.quit()
    return bsoup_obj

# %%
def assign_resource(resource_element):
    if (debug): print(resource_element)
    resource_url = resource_element.a['href']
    if (verbose): print("Found resource URL:", resource_url)
    resource_format = resource_element.a['data-format']
    if (verbose): print("Found resource format:", resource_format)
    return(resource_url, resource_format)

# %%
def download_to_local(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    if (os.path.isfile(local_file) == False):
        with requests.get(doc_path, stream=True) as r:
            with open(local_file, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print('Downladed file: ' + local_file)
    else:
        print('Skipped existing file: ' + local_file)

# %%
def download_to_gdrive(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
    dest_file = gdrivePrefix + local_file
    with requests.get(doc_path, stream=True) as r:
        with open(dest_file, 'wb') as f:
            shutil.copyfileobj(r.raw, f)
    print('Downladed file: ' + dest_file)

# %%
if (notifyStatus): email_notify("Phase 1 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 1. Perform the Scraping and Processing

# %%
if (notifyStatus): email_notify("Phase 2 Perform the Scraping and Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Setting up a dataframe to capture the records
df = pd.DataFrame(columns=['dataset_title', 'org_type', 'agency_name', 'dataset_url', 'description', 
                           'resource1_url', 'resource1_format', 'resource2_url', 'resource2_format', 
                           'resource3_url', 'resource3_format', 'resource4_url', 'resource4_format', 
                           'resource5_url', 'resource5_format', 'resource6_url', 'resource6_format'])

# %%
# Setting up the necessary operating parameters
num_entries = 0
done = False

# Defining the starting and ending page numbers to visit
num_pages = 1 # 1
max_pages = 500 # 13086

# %%
# Specifying the URL of desired web page to be scrapped
website_url = "https://catalog.data.gov"
dataset_page_url = website_url + "/dataset?page=" + str(num_pages)

# %%
while not done:
    # Gather all blog links from the blog page
    home_page_browser = access_url_bsoup(dataset_page_url)
    main_page_container = home_page_browser.find("section", class_="module")
    collection = main_page_container.find_all("li", class_="dataset-item")

    for item in collection:
        if (debug): print(item)
        org_type_element = item.find("span", class_="organization-type")
        if (org_type_element == None):
            org_type = '[Not Found]'
        else:
            org_type = org_type_element['data-organization-type']
            if (verbose): print("Found organization type:", org_type)

        data_heading_element = item.find("h3", class_="dataset-heading")
        if (data_heading_element == None):
            dataset_title = '[Not Found]'
            dataset_url = '[Not Found]'
        else:
            dataset_title = data_heading_element.a.text
            if (verbose): print("Found dataset title:", dataset_title)
            dataset_url = website_url + data_heading_element.a['href']
            if (verbose): print("Found dataset url:", dataset_url)

        org_name_element = item.find("p", class_="dataset-organization")
        if (org_name_element == None):
            agency_name = '[Not Found]'
        else:
            agency_name = org_name_element.text.rstrip(" —")
            if (verbose): print("Found agency name:", agency_name)

        description_element = item.find("div", class_="notes").div
        if (description_element == None):
            description = '[Not Found]'
        else:
            description = description_element.text
            if (verbose): print("Found dataset description:", description)

        resource1_url, resource1_format = '[Not Applicable]', '[Not Applicable]'
        resource2_url, resource2_format = '[Not Applicable]', '[Not Applicable]'
        resource3_url, resource3_format = '[Not Applicable]', '[Not Applicable]'
        resource4_url, resource4_format = '[Not Applicable]', '[Not Applicable]'
        resource5_url, resource5_format = '[Not Applicable]', '[Not Applicable]'
        resource6_url, resource6_format = '[Not Applicable]', '[Not Applicable]'
        data_resources_list = item.find("ul", class_="dataset-resources")
        if (data_resources_list != None):
            data_resources_element = data_resources_list.find_all("li")
            if (debug): print(data_resources_element)
            resource_index = 0
            for individual_res in data_resources_element:
                if (resource_index == 0): resource1_url, resource1_format = assign_resource(individual_res)
                if (resource_index == 1): resource2_url, resource2_format = assign_resource(individual_res)
                if (resource_index == 2): resource3_url, resource3_format = assign_resource(individual_res)
                if (resource_index == 3): resource4_url, resource4_format = assign_resource(individual_res)
                if (resource_index == 4): resource5_url, resource5_format = assign_resource(individual_res)
                if (resource_index == 5): resource6_url, resource6_format = assign_resource(individual_res)
                resource_index = resource_index + 1

        df.loc[num_entries] = [dataset_title, org_type, agency_name, dataset_url, description,
                               resource1_url, resource1_format, resource2_url, resource2_format,
                               resource3_url, resource3_format, resource4_url, resource4_format,
                               resource5_url, resource5_format, resource6_url, resource6_format]
        num_entries = num_entries + 1

    if ((num_pages % 100)==0): email_notify("Finished parsing page number " + str(num_pages) + " at " + datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
    pagination_css = home_page_browser.find("div", class_="pagination")
    active_page = int(pagination_css.find("li", class_="active").text)
    if (active_page == max_pages):
        done = True
    else:
        num_pages = num_pages + 1
        dataset_page_url = website_url + "/dataset?page=" + str(num_pages)
# Out:
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=1
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=1
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=2
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=2
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=3
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=3
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=4
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=4
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=5
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=5
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=6
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=6
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=7
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=7
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=8
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=8
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=9
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=9
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=10
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=10
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=11
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=11
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=12
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=12
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=13
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=13
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=14
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=14
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=15
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=15
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=16
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=16
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=17
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=17
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=18
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=18
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=19
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=19
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=20
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=20
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=21
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=21
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=22
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=22
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=23
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=23
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=24
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=24
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=25
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=25
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=26
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=26
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=27
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=27
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=28
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=28
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=29
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=29
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=30
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=30
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=31
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=31
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=32
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=32
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=33
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=33
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=34
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=34
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=35
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=35
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=36
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=36
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=37
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=37
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=38
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=38
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=39
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=39
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=40
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=40
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=41
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=41
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=42
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=42
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=43
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=43
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=44
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=44
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=45
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=45
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=46
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=46
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=47
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=47
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=48
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=48
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=49
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=49
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=50
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=50
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=51
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=51
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=52
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=52
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=53
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=53
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=54
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=54
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=55
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=55
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=56
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=56
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=57
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=57
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=58
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=58
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=59
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=59
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=60
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=60
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=61
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=61
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=62
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=62
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=63
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=63
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=64
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=64
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=65
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=65
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=66
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=66
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=67
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=67
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=68
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=68
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=69
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=69
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=70
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=70
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=71
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=71
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=72
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=72
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=73
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=73
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=74
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=74
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=75
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=75
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=76
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=76
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=77
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=77
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=78
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=78
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=79
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=79
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=80
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=80
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=81
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=81
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=82
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=82
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=83
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=83
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=84
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=84
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=85
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=85
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=86
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=86
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=87
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=87
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=88
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=88
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=89
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=89
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=90
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=90
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=91
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=91
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=92
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=92
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=93
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=93
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=94
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=94
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=95
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=95
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=96
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=96
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=97
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=97
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=98
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=98
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=99
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=99
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=100
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=100
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=101
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=101
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=102
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=102
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=103
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=103
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=104
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=104
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=105
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=105
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=106
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=106
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=107
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=107
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=108
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=108
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=109
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=109
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=110
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=110
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=111
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=111
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=112
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=112
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=113
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=113
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=114
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=114
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=115
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=115
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=116
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=116
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=117
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=117
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=118
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=118
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=119
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=119
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=120
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=120
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=121
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=121
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=122
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=122
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=123
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=123
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=124
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=124
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=125
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=125
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=126
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=126
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=127
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=127
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=128
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=128
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=129
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=129
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=130
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=130
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=131
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=131
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=132
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=132
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=133
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=133
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=134
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=134
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=135
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=135
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=136
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=136
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=137
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=137
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=138
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=138
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=139
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=139
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=140
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=140
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=141
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=141
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=142
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=142
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=143
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=143
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=144
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=144
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=145
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=145
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=146
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=146
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=147
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=147
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=148
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=148
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=149
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=149
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=150
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=150
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=151
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=151
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=152
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=152
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=153
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=153
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=154
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=154
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=155
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=155
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=156
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=156
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=157
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=157
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=158
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=158
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=159
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=159
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=160
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=160
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=161
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=161
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=162
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=162
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=163
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=163
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=164
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=164
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=165
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=165
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=166
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=166
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=167
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=167
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=168
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=168
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=169
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=169
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=170
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=170
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=171
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=171
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=172
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=172
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=173
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=173
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=174
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=174
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=175
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=175
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=176
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=176
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=177
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=177
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=178
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=178
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=179
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=179
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=180
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=180
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=181
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=181
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=182
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=182
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=183
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=183
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=184
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=184
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=185
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=185
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=186
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=186
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=187
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=187
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=188
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=188
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=189
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=189
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=190
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=190
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=191
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=191
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=192
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=192
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=193
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=193
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=194
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=194
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=195
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=195
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=196
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=196
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=197
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=197
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=198
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=198
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=199
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=199
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=200
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=200
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=201
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=201
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=202
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=202
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=203
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=203
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=204
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=204
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=205
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=205
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=206
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=206
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=207
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=207
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=208
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=208
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=209
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=209
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=210
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=210
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=211
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=211
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=212
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=212
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=213
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=213
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=214
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=214
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=215
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=215
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=216
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=216
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=217
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=217
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=218
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=218
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=219
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=219
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=220
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=220
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=221
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=221
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=222
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=222
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=223
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=223
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=224
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=224
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=225
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=225
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=226
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=226
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=227
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=227
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=228
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=228
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=229
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=229
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=230
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=230
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=231
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=231
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=232
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=232
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=233
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=233
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=234
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=234
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=235
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=235
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=236
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=236
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=237
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=237
# Waiting 5 seconds to finish retrieving the URL.
# ...
# Attempting to access the web page: https://catalog.data.gov/dataset?page=422
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=422
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=423
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=423
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=424
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=424
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=425
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=425
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=426
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=426
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=427
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=427
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=428
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=428
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=429
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=429
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=430
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=430
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=431
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=431
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=432
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=432
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=433
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=433
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=434
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=434
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=435
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=435
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=436
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=436
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=437
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=437
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=438
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=438
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=439
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=439
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=440
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=440
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=441
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=441
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=442
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=442
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=443
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=443
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=444
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=444
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=445
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=445
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=446
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=446
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=447
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=447
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=448
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=448
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=449
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=449
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=450
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=450
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=451
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=451
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=452
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=452
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=453
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=453
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=454
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=454
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=455
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=455
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=456
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=456
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=457
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=457
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=458
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=458
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=459
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=459
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=460
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=460
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=461
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=461
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=462
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=462
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=463
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=463
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=464
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=464
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=465
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=465
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=466
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=466
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=467
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=467
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=468
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=468
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=469
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=469
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=470
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=470
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=471
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=471
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=472
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=472
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=473
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=473
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=474
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=474
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=475
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=475
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=476
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=476
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=477
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=477
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=478
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=478
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=479
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=479
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=480
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=480
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=481
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=481
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=482
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=482
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=483
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=483
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=484
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=484
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=485
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=485
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=486
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=486
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=487
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=487
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=488
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=488
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=489
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=489
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=490
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=490
# Waiting 4 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=491
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=491
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=492
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=492
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=493
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=493
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=494
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=494
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=495
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=495
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=496
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=496
# Waiting 3 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=497
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=497
# Waiting 5 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=498
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=498
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=499
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=499
# Waiting 6 seconds to finish retrieving the URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=500
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=500

# %%
print('Finished finding all available web pages:', num_pages)
print('Total datasets processed:', num_entries)
# Out:
# Finished finding all available web pages: 500
# Total datasets processed: 9865

# %%
if (writeToJSON):
    out_file = df.to_json(orient='records')
    with open('web-scraping-py-bsoup-datagov-datasets.json', 'w') as f:
        f.write(out_file)

# %%
if (notifyStatus): email_notify("Phase 2 Perform the Scraping and Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:57:17.814986
