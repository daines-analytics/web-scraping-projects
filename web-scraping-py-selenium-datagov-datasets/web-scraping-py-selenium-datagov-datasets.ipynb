# %% [markdown]
# # Web Scraping of Data.gov Dataset Catalog Using Python and Selenium
# ### David Lowe
# ### February 7, 2020
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific pieces of information from a website. The Python web scraping code leverages the Selenium module.
#
# INTRODUCTION: Data.gov is a government data repository website managed and hosted by the U.S. General Services Administration. The purpose of this exercise is to practice web scraping by gathering the dataset entries from Data.gov’s web pages. This iteration of the script automatically traverses the web pages to capture all dataset entries and store all captured information in a JSON output file.
#
# Starting URLs: https://catalog.data.gov/dataset

# %% [markdown]
# ## Section 1. Prepare Environment

# %%
import os
import shutil
import smtplib
import sys
import pandas as pd
from email.message import EmailMessage
from datetime import datetime
from random import randint
from time import sleep
# import requests
# from requests.exceptions import HTTPError
# from requests.exceptions import ConnectionError
# from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose and debug flags to print detailed messages for debugging (setting True will activate!)
verbose = False
debug = False

# Set up the flag to send status emails (setting to True will send the status emails!)
notifyStatus = False

# Set up the flag to write the output to a JSON document (setting to TRUE will create the document!)
writeToJSON = True

# Set up the mountStorage flag to mount G Drive for storing files (setting True will mount the drive!)
mountStorage = False

# Set up the executeDownload flag to download files (setting True will download!)
executeDownload = False

# %%
# Colab-Specific Setup - Mount Google Drive for storing downloaded files
if (mountStorage):
    from google.colab import drive
    drive.mount('/content/gdrive')

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Web Scraping Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
def access_url_bsoup(url):
    # Creating an html document from the URL
    uastring = "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0"
    headers={'User-Agent': uastring}
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(3,6)
    print("Waiting " + str(waitTime) + " seconds to finish retrieving the URL.")
    sleep(waitTime)
    print('Attempting to access the web page: ' + url)
    try:
        s = requests.Session()
        resp = s.get(url, headers=headers)
        if (debug): print(resp.text)
    except HTTPError as e:
        print('The server could not serve up the web page!')
        sys.exit("Script processing cannot continue!!!")
    except ConnectionError as e:
        print('The server could not be reached due to connection issues!')
        sys.exit("Script processing cannot continue!!!")

    if (resp.status_code==requests.codes.ok):
        print('Successfully accessed the web page: ' + url)
        bsoup_obj = BeautifulSoup(resp.text, 'lxml')
        return(bsoup_obj)

# %%
def assign_resource(resource_element):
    if (debug): print(resource_element)
    resource_url = resource_element.find_element_by_tag_name('a').get_attribute('href')
    if (verbose): print("Found resource URL:", resource_url)
    resource_format = resource_element.find_element_by_tag_name('a').get_attribute('data-format')
    if (verbose): print("Found resource format:", resource_format)
    return(resource_url, resource_format)

# %%
def download_to_local(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    if (os.path.isfile(local_file) == False):
        with requests.get(doc_path, stream=True) as r:
            with open(local_file, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print('Downladed file: ' + local_file)
    else:
        print('Skipped existing file: ' + local_file)

# %%
def download_to_gdrive(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
    dest_file = gdrivePrefix + local_file
    with requests.get(doc_path, stream=True) as r:
        with open(dest_file, 'wb') as f:
            shutil.copyfileobj(r.raw, f)
    print('Downladed file: ' + dest_file)

# %%
if (notifyStatus): email_notify("Phase 1 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 1. Perform the Scraping and Processing

# %%
if (notifyStatus): email_notify("Phase 2 Perform the Scraping and Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Setting up a dataframe to capture the records
df = pd.DataFrame(columns=['dataset_title', 'org_type', 'agency_name', 'dataset_url', 'description', 
                           'resource1_url', 'resource1_format', 'resource2_url', 'resource2_format', 
                           'resource3_url', 'resource3_format', 'resource4_url', 'resource4_format', 
                           'resource5_url', 'resource5_format', 'resource6_url', 'resource6_format'])

# %%
# Setting up the necessary operating parameters
num_entries = 0
done = False

# Defining the starting and ending page numbers to visit
num_pages = 501 # 1
max_pages = 600 # 13086

# %%
# Specifying the URL of desired web page to be scrapped
website_url = "https://catalog.data.gov"
dataset_page_url = website_url + "/dataset?page=" + str(num_pages)

# %%
# Initialize the web browser
firefox_options = Options()
firefox_options.headless = False
home_page_browser = webdriver.Firefox(options=firefox_options)

# %%
while not done:
    # Gather all blog links from the blog page
    print('Attempting to access the web page:', dataset_page_url)
    try:
        home_page_browser.get(dataset_page_url)
        print('Successfully accessed the web page:', dataset_page_url)
    except:
        print('The server could not serve up the web page!')
        sys.exit('Script processing cannot continue!!!')
    main_page_container = home_page_browser.find_element_by_css_selector('section.module')
    collection = main_page_container.find_elements_by_css_selector('li.dataset-item')

    for item in collection:
        if (debug): print(item)
        try:
            org_type_element = item.find_element_by_css_selector('span.organization-type')
            org_type = org_type_element.get_attribute('data-organization-type')
            if (verbose): print("Found organization type:", org_type)
        except:
            org_type = '[Not Found]'

        try:
            data_heading_element = item.find_element_by_css_selector('h3.dataset-heading')
            dataset_title = data_heading_element.find_element_by_tag_name('a').text
            if (verbose): print("Found dataset title:", dataset_title)
            dataset_url = website_url + data_heading_element.find_element_by_tag_name('a').get_attribute('href')
            if (verbose): print("Found dataset url:", dataset_url)
        except:
            dataset_title = '[Not Found]'
            dataset_url = '[Not Found]'

        try:
            org_name_element = item.find_element_by_css_selector('p.dataset-organization')
            agency_name = org_name_element.text.rstrip(" —")
            if (verbose): print("Found agency name:", agency_name)
        except:
            agency_name = '[Not Found]'

        try:
            description_element = item.find_element_by_css_selector('div.notes').find_element_by_tag_name('div')
            description = description_element.text
            if (verbose): print("Found dataset description:", description)
        except:
            description = '[Not Found]'

        resource1_url, resource1_format = '[Not Applicable]', '[Not Applicable]'
        resource2_url, resource2_format = '[Not Applicable]', '[Not Applicable]'
        resource3_url, resource3_format = '[Not Applicable]', '[Not Applicable]'
        resource4_url, resource4_format = '[Not Applicable]', '[Not Applicable]'
        resource5_url, resource5_format = '[Not Applicable]', '[Not Applicable]'
        resource6_url, resource6_format = '[Not Applicable]', '[Not Applicable]'
        try:
            data_resources_list = item.find_element_by_css_selector('ul.dataset-resources')
            if (data_resources_list != None):
                data_resources_element = data_resources_list.find_elements_by_tag_name('li')
                if (debug): print(data_resources_element)
                resource_index = 0
                for individual_res in data_resources_element:
                    if (resource_index == 0): resource1_url, resource1_format = assign_resource(individual_res)
                    if (resource_index == 1): resource2_url, resource2_format = assign_resource(individual_res)
                    if (resource_index == 2): resource3_url, resource3_format = assign_resource(individual_res)
                    if (resource_index == 3): resource4_url, resource4_format = assign_resource(individual_res)
                    if (resource_index == 4): resource5_url, resource5_format = assign_resource(individual_res)
                    if (resource_index == 5): resource6_url, resource6_format = assign_resource(individual_res)
                    resource_index = resource_index + 1
        except:
            pass

        df.loc[num_entries] = [dataset_title, org_type, agency_name, dataset_url, description,
                               resource1_url, resource1_format, resource2_url, resource2_format,
                               resource3_url, resource3_format, resource4_url, resource4_format,
                               resource5_url, resource5_format, resource6_url, resource6_format]
        num_entries = num_entries + 1

    if (((num_pages % 100)==0) & notifyStatus): email_notify("Finished parsing page number " + str(num_pages) + " at " + datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
    pagination_css = home_page_browser.find_element_by_css_selector('div.pagination')
    active_page = int(pagination_css.find_element_by_css_selector('li.active').text)
    if (active_page == max_pages):
        done = True
    else:
        num_pages = num_pages + 1
        dataset_page_url = website_url + "/dataset?page=" + str(num_pages)
        # Adding random wait time so we do not hammer the website needlessly
        waitTime = randint(3,5)
        print("Waiting " + str(waitTime) + " seconds to retrieve the next URL.")
        sleep(waitTime)
# Out:
# Attempting to access the web page: https://catalog.data.gov/dataset?page=501
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=501
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=502
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=502
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=503
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=503
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=504
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=504
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=505
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=505
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=506
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=506
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=507
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=507
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=508
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=508
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=509
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=509
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=510
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=510
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=511
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=511
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=512
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=512
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=513
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=513
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=514
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=514
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=515
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=515
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=516
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=516
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=517
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=517
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=518
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=518
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=519
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=519
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=520
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=520
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=521
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=521
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=522
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=522
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=523
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=523
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=524
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=524
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=525
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=525
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=526
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=526
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=527
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=527
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=528
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=528
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=529
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=529
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=530
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=530
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=531
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=531
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=532
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=532
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=533
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=533
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=534
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=534
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=535
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=535
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=536
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=536
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=537
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=537
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=538
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=538
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=539
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=539
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=540
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=540
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=541
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=541
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=542
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=542
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=543
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=543
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=544
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=544
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=545
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=545
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=546
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=546
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=547
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=547
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=548
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=548
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=549
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=549
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=550
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=550
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=551
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=551
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=552
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=552
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=553
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=553
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=554
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=554
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=555
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=555
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=556
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=556
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=557
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=557
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=558
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=558
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=559
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=559
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=560
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=560
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=561
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=561
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=562
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=562
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=563
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=563
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=564
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=564
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=565
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=565
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=566
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=566
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=567
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=567
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=568
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=568
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=569
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=569
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=570
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=570
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=571
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=571
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=572
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=572
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=573
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=573
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=574
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=574
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=575
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=575
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=576
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=576
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=577
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=577
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=578
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=578
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=579
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=579
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=580
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=580
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=581
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=581
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=582
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=582
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=583
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=583
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=584
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=584
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=585
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=585
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=586
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=586
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=587
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=587
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=588
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=588
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=589
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=589
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=590
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=590
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=591
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=591
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=592
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=592
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=593
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=593
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=594
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=594
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=595
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=595
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=596
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=596
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=597
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=597
# Waiting 5 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=598
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=598
# Waiting 3 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=599
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=599
# Waiting 4 seconds to retrieve the next URL.
# Attempting to access the web page: https://catalog.data.gov/dataset?page=600
# Successfully accessed the web page: https://catalog.data.gov/dataset?page=600

# %%
home_page_browser.quit()
print('Finished finding all available web pages:', num_pages)
print('Total datasets processed:', num_entries)
# Out:
# Finished finding all available web pages: 600
# Total datasets processed: 2000

# %%
if (writeToJSON):
    out_file = df.to_json(orient='records')
    with open('web-scraping-py-selenium-datagov-datasets.json', 'w') as f:
        f.write(out_file)

# %%
if (notifyStatus): email_notify("Phase 2 Perform the Scraping and Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:18:10.926113
