# %% [markdown]
# # Web Scraping of Machine Learning Mastery Articles Using BeautifulSoup
# ### David Lowe
# ### August 26, 2022
#
# SUMMARY: This project aims to practice web scraping by extracting specific pieces of information from a website. The web scraping Python code leverages the BeautifulSoup module.
#
# INTRODUCTION: Dr. Jason Brownlee’s Machine Learning Mastery hosts its tutorial lessons at https://machinelearningmastery.com/blog. The purpose of this exercise is to practice web scraping by gathering the blog entries from Machine Learning Mastery’s web pages. This iteration of the script automatically traverses the web pages to capture all articles and store the captured information in a CSV output file for sorting and filtering.
#
# Starting URL: https://machinelearningmastery.com/blog

# %% [markdown]
# ## Task 1. Prepare Environment

# %%
import sys
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
from random import randint
from time import sleep

# %%
# Set the starting time for calculating script duration
startTimeScript = datetime.now()

# Specifying the website and browsing parameters
WEBSITE_URL = 'https://machinelearningmastery.com/blog'
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.5112.81 Safari/537.36 Edg/104.0.1293.54'

# %% [markdown]
# ## Task 2. Get Blog Article Headings

# %%
def access_web_page(url=WEBSITE_URL):
    headers = {'user-agent': USER_AGENT}
    try:
        sess = requests.Session()
        resp = sess.get(url, headers=headers)
        # print(resp.text)
    except requests.HTTPError as e:
        print('The server could not serve up the web page with error code:', e)
        sys.exit("Script processing cannot continue!!!")
    except requests.ConnectionError as e:
        print('The server could not be reached due to connection issues with error code:', e)
        sys.exit("Script processing cannot continue!!!")

    if resp.status_code==requests.codes.ok :
        print('Successfully accessed the web page: ' + url)
        web_page = BeautifulSoup(resp.text, 'lxml')
        return web_page

# %%
df_article = pd.DataFrame(columns=['title','url','date','author','category','summary'])
i = 0  # Number of article entries processed
j = 0  # Number of web pages processed
article_page = access_web_page()
done = False
max_pages = 121

while not done :
    article_list = article_page.find_all('article')
    for article_item in article_list:
        blog_title = article_item.header.h2.string
        blog_url = article_item.a["href"]
        blog_date = article_item.abbr.string
        blog_author = article_item.find(class_="fn").a.string
        blog_category = article_item.find(class_="categories").a.string
        blog_summary = article_item.section.p.string
        df_article.loc[i] = [blog_title, blog_url, blog_date,
                             blog_author,blog_category, blog_summary]
        i += 1
        # print(blog_title, blog_url, blog_date, blog_author,blog_category, blog_summary)

    j += 1
    print('Number of web pages processed so far:', j)
    print('Number of articles processed so far:', i)
    next_page_css = article_page.find(class_="next page-numbers")

    if (next_page_css is not None) and (j <= max_pages) :
        next_page_url = next_page_css["href"]
        # Adding a random wait time for accessing web pages
        waitTime = randint(4, 9)
        print("Waiting " + str(waitTime) + " seconds before retrieving the next URL.")
        sleep(waitTime)
        web_page = access_web_page(next_page_url)
    else :
        done = True
# Out:
# Successfully accessed the web page: https://machinelearningmastery.com/blog
# Number of web pages processed so far: 1
# Number of articles processed so far: 10
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 2
# Number of articles processed so far: 20
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 3
# Number of articles processed so far: 30
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 4
# Number of articles processed so far: 40
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 5
# Number of articles processed so far: 50
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 6
# Number of articles processed so far: 60
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 7
# Number of articles processed so far: 70
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 8
# Number of articles processed so far: 80
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 9
# Number of articles processed so far: 90
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 10
# Number of articles processed so far: 100
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 11
# Number of articles processed so far: 110
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 12
# Number of articles processed so far: 120
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 13
# Number of articles processed so far: 130
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 14
# Number of articles processed so far: 140
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 15
# Number of articles processed so far: 150
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 16
# Number of articles processed so far: 160
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 17
# Number of articles processed so far: 170
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 18
# Number of articles processed so far: 180
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 19
# Number of articles processed so far: 190
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 20
# Number of articles processed so far: 200
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 21
# Number of articles processed so far: 210
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 22
# Number of articles processed so far: 220
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 23
# Number of articles processed so far: 230
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 24
# Number of articles processed so far: 240
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 25
# Number of articles processed so far: 250
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 26
# Number of articles processed so far: 260
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 27
# Number of articles processed so far: 270
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 28
# Number of articles processed so far: 280
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 29
# Number of articles processed so far: 290
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 30
# Number of articles processed so far: 300
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 31
# Number of articles processed so far: 310
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 32
# Number of articles processed so far: 320
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 33
# Number of articles processed so far: 330
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 34
# Number of articles processed so far: 340
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 35
# Number of articles processed so far: 350
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 36
# Number of articles processed so far: 360
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 37
# Number of articles processed so far: 370
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 38
# Number of articles processed so far: 380
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 39
# Number of articles processed so far: 390
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 40
# Number of articles processed so far: 400
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 41
# Number of articles processed so far: 410
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 42
# Number of articles processed so far: 420
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 43
# Number of articles processed so far: 430
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 44
# Number of articles processed so far: 440
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 45
# Number of articles processed so far: 450
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 46
# Number of articles processed so far: 460
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 47
# Number of articles processed so far: 470
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 48
# Number of articles processed so far: 480
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 49
# Number of articles processed so far: 490
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 50
# Number of articles processed so far: 500
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 51
# Number of articles processed so far: 510
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 52
# Number of articles processed so far: 520
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 53
# Number of articles processed so far: 530
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 54
# Number of articles processed so far: 540
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 55
# Number of articles processed so far: 550
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 56
# Number of articles processed so far: 560
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 57
# Number of articles processed so far: 570
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 58
# Number of articles processed so far: 580
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 59
# Number of articles processed so far: 590
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 60
# Number of articles processed so far: 600
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 61
# Number of articles processed so far: 610
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 62
# Number of articles processed so far: 620
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 63
# Number of articles processed so far: 630
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 64
# Number of articles processed so far: 640
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 65
# Number of articles processed so far: 650
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 66
# Number of articles processed so far: 660
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 67
# Number of articles processed so far: 670
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 68
# Number of articles processed so far: 680
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 69
# Number of articles processed so far: 690
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 70
# Number of articles processed so far: 700
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 71
# Number of articles processed so far: 710
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 72
# Number of articles processed so far: 720
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 73
# Number of articles processed so far: 730
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 74
# Number of articles processed so far: 740
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 75
# Number of articles processed so far: 750
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 76
# Number of articles processed so far: 760
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 77
# Number of articles processed so far: 770
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 78
# Number of articles processed so far: 780
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 79
# Number of articles processed so far: 790
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 80
# Number of articles processed so far: 800
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 81
# Number of articles processed so far: 810
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 82
# Number of articles processed so far: 820
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 83
# Number of articles processed so far: 830
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 84
# Number of articles processed so far: 840
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 85
# Number of articles processed so far: 850
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 86
# Number of articles processed so far: 860
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 87
# Number of articles processed so far: 870
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 88
# Number of articles processed so far: 880
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 89
# Number of articles processed so far: 890
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 90
# Number of articles processed so far: 900
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 91
# Number of articles processed so far: 910
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 92
# Number of articles processed so far: 920
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 93
# Number of articles processed so far: 930
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 94
# Number of articles processed so far: 940
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 95
# Number of articles processed so far: 950
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 96
# Number of articles processed so far: 960
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 97
# Number of articles processed so far: 970
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 98
# Number of articles processed so far: 980
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 99
# Number of articles processed so far: 990
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 100
# Number of articles processed so far: 1000
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 101
# Number of articles processed so far: 1010
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 102
# Number of articles processed so far: 1020
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 103
# Number of articles processed so far: 1030
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 104
# Number of articles processed so far: 1040
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 105
# Number of articles processed so far: 1050
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 106
# Number of articles processed so far: 1060
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 107
# Number of articles processed so far: 1070
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 108
# Number of articles processed so far: 1080
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 109
# Number of articles processed so far: 1090
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 110
# Number of articles processed so far: 1100
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 111
# Number of articles processed so far: 1110
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 112
# Number of articles processed so far: 1120
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 113
# Number of articles processed so far: 1130
# Waiting 9 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 114
# Number of articles processed so far: 1140
# Waiting 8 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 115
# Number of articles processed so far: 1150
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 116
# Number of articles processed so far: 1160
# Waiting 7 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 117
# Number of articles processed so far: 1170
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 118
# Number of articles processed so far: 1180
# Waiting 6 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 119
# Number of articles processed so far: 1190
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 120
# Number of articles processed so far: 1200
# Waiting 4 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 121
# Number of articles processed so far: 1210
# Waiting 5 seconds before retrieving the next URL.
# Successfully accessed the web page: https://machinelearningmastery.com/blog/page/2/
# Number of web pages processed so far: 122
# Number of articles processed so far: 1220

# %% [markdown]
# ### Task 3 Organize Data and Produce Outputs

# %%
# out_file = df_article.to_csv(index=False)
out_file = df_article.to_csv(index=False, line_terminator = '\r')
with open('py_webscraping_beautifulsoup_mlmastery_articles.csv', 'w', encoding="utf-8") as f:
    f.write(out_file)
print('Total number of articles found:', len(df_article))
# Out:
# Total number of articles found: 1220

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:13:08.970881
