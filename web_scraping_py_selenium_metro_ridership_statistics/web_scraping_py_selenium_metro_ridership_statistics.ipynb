# %% [markdown]
# # Web Scraping of Metro Ridership Statistics Using Python and Selenium
# ### David Lowe
# ### August 14, 2020
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific pieces of information from a website. The Python web scraping code leverages the Selenium module.
#
# INTRODUCTION: Metro is a transportation planner and coordinator, designer, builder and operator for one of the country’s largest, most populous counties, Los Angeles. More than 9.6 million people, nearly one-third of California’s residents, live, work and play within its 1,433-square-mile service area. The purpose of this exercise is to practice web scraping by gathering the bus ridership statistics from the agency's web pages. This iteration of the script automatically traverses the monthly web pages (from January 2009 to June 2020) to capture all bus ridership entries and store the information in a CSV output file.
#
# Starting URLs: http://isotp.metro.net/MetroRidership/Index.aspx

# %% [markdown]
# ## Task 1. Prepare Environment

# %%
import os
import sys
import pandas as pd
import shutil
import boto3
from datetime import datetime, date
from random import randint
from time import sleep
from dotenv import load_dotenv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.webdriver.support.select import Select
from selenium.webdriver.firefox.options import Options

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose and debug flags to print detailed messages for debugging (setting True will activate!)
verbose = False
debug = False

# Set up the flag to send status emails (setting to True will send the status emails!)
notifyStatus = False

# # Set up the parent directory location for loading the dotenv files
# useColab = False
# if useColab:
#     # Mount Google Drive locally for storing files
#     from google.colab import drive
#     drive.mount('/content/gdrive')
#     gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
#     env_path = '/content/gdrive/My Drive/Colab Notebooks/'
#     dotenv_path = env_path + "python_script.env"
#     load_dotenv(dotenv_path=dotenv_path)

# # Set up the dotenv file for retrieving environment variables
# useLocalPC = False
# if useLocalPC:
#     env_path = "/Users/david/PycharmProjects/"
#     dotenv_path = env_path + "python_script.env"
#     load_dotenv(dotenv_path=dotenv_path)

# Set up the flag to write the output to a JSON document (setting to TRUE will create the document!)
writeOutput = True

# Set up the executeDownload flag to download files (setting True will download!)
executeDownload = False

# %%
# Set up the email notification function
def status_notify(msg_text):
    access_key = os.environ.get('SNS_ACCESS_KEY')
    secret_key = os.environ.get('SNS_SECRET_KEY')
    aws_region = os.environ.get('SNS_AWS_REGION')
    topic_arn = os.environ.get('SNS_TOPIC_ARN')
    if (access_key is None) or (secret_key is None) or (aws_region is None):
        sys.exit("Incomplete notification setup info. Script Processing Aborted!!!")
    sns = boto3.client('sns', aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name=aws_region)
    response = sns.publish(TopicArn=topic_arn, Message=msg_text)
    if response['ResponseMetadata']['HTTPStatusCode'] != 200 :
        print('Status notification not OK with HTTP status code:', response['ResponseMetadata']['HTTPStatusCode'])

# %%
if (notifyStatus): status_notify("Task 1 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Task 2. Perform the Scraping and Processing

# %%
if (notifyStatus): status_notify("Task 2 Perform the Scraping and Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Setting up a dataframe to capture the records
df = pd.DataFrame(columns=['idx', 'values'])
num_entries = 0

# %%
# Specifying the URL of desired web page to be scrapped
website_url = "http://isotp.metro.net/MetroRidership"
dataset_page_url = website_url + "/Index.aspx"

# %%
# Initialize the web browser
firefox_options = Options()
firefox_options.headless = False
home_page_browser = webdriver.Firefox(options=firefox_options)

# %%
# Gather all blog links from the blog page
print('Attempting to access the web page:', dataset_page_url)
try:
    home_page_browser.get(dataset_page_url)
    print('Successfully accessed the web page:', dataset_page_url)
except:
    print('The server could not serve up the web page!')
    sys.exit('Script processing cannot continue!!!')

last_period = date(2020, 6, 1)
data_years = range(2009, 2021)
data_months = range(1, 13)

for year in data_years:
    for month in data_months:
        current_period = date(year, month, 1)
        if current_period > last_period: break

        # Adding random wait time so we do not hammer the website needlessly
        waitTime = randint(2,5)
        print("Waiting", waitTime, "seconds to retrieve year", year, "and month", month)
        sleep(waitTime)

        select_element = home_page_browser.find_element(By.NAME, "ctl00$ContentPlaceHolder1$ddlYear")
        select_year = Select(select_element)
        select_year.select_by_value(str(year))

        select_element = home_page_browser.find_element(By.NAME, "ctl00$ContentPlaceHolder1$ddlPeriod")
        select_month = Select(select_element)
        select_month.select_by_value(str(month))

        select_element = home_page_browser.find_element(By.NAME, "ctl00$ContentPlaceHolder1$btnSubmit")
        select_element.click()
        
        select_element = home_page_browser.find_element(By.ID, "ContentPlaceHolder1_rpAllBus_gvAllBus")
        table_rows = select_element.find_elements(By.TAG_NAME, "tr")
        target_row = table_rows[4]
        ridership = int(target_row.find_elements(By.TAG_NAME, 'td')[4].text.replace(',',''))
        print("Captured bus ridership of", ridership, "for the period of", current_period, )

        df.loc[num_entries] = [current_period, ridership]
        num_entries = num_entries + 1
# Out:
# Attempting to access the web page: http://isotp.metro.net/MetroRidership/Index.aspx
# Successfully accessed the web page: http://isotp.metro.net/MetroRidership/Index.aspx
# Waiting 2 seconds to retrieve year 2009 and month 1
# Captured bus ridership of 30580085 for the period of 2009-01-01
# Waiting 3 seconds to retrieve year 2009 and month 2
# Captured bus ridership of 28778916 for the period of 2009-02-01
# Waiting 2 seconds to retrieve year 2009 and month 3
# Captured bus ridership of 32963302 for the period of 2009-03-01
# Waiting 2 seconds to retrieve year 2009 and month 4
# Captured bus ridership of 31471512 for the period of 2009-04-01
# Waiting 3 seconds to retrieve year 2009 and month 5
# Captured bus ridership of 31665879 for the period of 2009-05-01
# Waiting 5 seconds to retrieve year 2009 and month 6
# Captured bus ridership of 31242816 for the period of 2009-06-01
# Waiting 4 seconds to retrieve year 2009 and month 7
# Captured bus ridership of 31233738 for the period of 2009-07-01
# Waiting 3 seconds to retrieve year 2009 and month 8
# Captured bus ridership of 30359286 for the period of 2009-08-01
# Waiting 3 seconds to retrieve year 2009 and month 9
# Captured bus ridership of 31208520 for the period of 2009-09-01
# Waiting 4 seconds to retrieve year 2009 and month 10
# Captured bus ridership of 32487588 for the period of 2009-10-01
# Waiting 3 seconds to retrieve year 2009 and month 11
# Captured bus ridership of 29816960 for the period of 2009-11-01
# Waiting 5 seconds to retrieve year 2009 and month 12
# Captured bus ridership of 29174539 for the period of 2009-12-01
# Waiting 2 seconds to retrieve year 2010 and month 1
# Captured bus ridership of 27816661 for the period of 2010-01-01
# Waiting 2 seconds to retrieve year 2010 and month 2
# Captured bus ridership of 28043658 for the period of 2010-02-01
# Waiting 5 seconds to retrieve year 2010 and month 3
# Captured bus ridership of 32608994 for the period of 2010-03-01
# Waiting 4 seconds to retrieve year 2010 and month 4
# Captured bus ridership of 31082930 for the period of 2010-04-01
# Waiting 2 seconds to retrieve year 2010 and month 5
# Captured bus ridership of 31216542 for the period of 2010-05-01
# Waiting 4 seconds to retrieve year 2010 and month 6
# Captured bus ridership of 30926539 for the period of 2010-06-01
# Waiting 5 seconds to retrieve year 2010 and month 7
# Captured bus ridership of 29619433 for the period of 2010-07-01
# Waiting 4 seconds to retrieve year 2010 and month 8
# Captured bus ridership of 29836011 for the period of 2010-08-01
# Waiting 5 seconds to retrieve year 2010 and month 9
# Captured bus ridership of 30100295 for the period of 2010-09-01
# Waiting 3 seconds to retrieve year 2010 and month 10
# Captured bus ridership of 30385617 for the period of 2010-10-01
# Waiting 4 seconds to retrieve year 2010 and month 11
# Captured bus ridership of 28932370 for the period of 2010-11-01
# Waiting 5 seconds to retrieve year 2010 and month 12
# Captured bus ridership of 27659766 for the period of 2010-12-01
# Waiting 5 seconds to retrieve year 2011 and month 1
# Captured bus ridership of 28581220 for the period of 2011-01-01
# Waiting 5 seconds to retrieve year 2011 and month 2
# Captured bus ridership of 27820713 for the period of 2011-02-01
# Waiting 4 seconds to retrieve year 2011 and month 3
# Captured bus ridership of 31773482 for the period of 2011-03-01
# Waiting 5 seconds to retrieve year 2011 and month 4
# Captured bus ridership of 30448725 for the period of 2011-04-01
# Waiting 5 seconds to retrieve year 2011 and month 5
# Captured bus ridership of 31367580 for the period of 2011-05-01
# Waiting 4 seconds to retrieve year 2011 and month 6
# Captured bus ridership of 30735182 for the period of 2011-06-01
# Waiting 4 seconds to retrieve year 2011 and month 7
# Captured bus ridership of 28974201 for the period of 2011-07-01
# Waiting 3 seconds to retrieve year 2011 and month 8
# Captured bus ridership of 30336164 for the period of 2011-08-01
# Waiting 3 seconds to retrieve year 2011 and month 9
# Captured bus ridership of 30554067 for the period of 2011-09-01
# Waiting 5 seconds to retrieve year 2011 and month 10
# Captured bus ridership of 31111034 for the period of 2011-10-01
# Waiting 3 seconds to retrieve year 2011 and month 11
# Captured bus ridership of 29195092 for the period of 2011-11-01
# Waiting 3 seconds to retrieve year 2011 and month 12
# Captured bus ridership of 28707109 for the period of 2011-12-01
# Waiting 5 seconds to retrieve year 2012 and month 1
# Captured bus ridership of 29124065 for the period of 2012-01-01
# Waiting 2 seconds to retrieve year 2012 and month 2
# Captured bus ridership of 29497770 for the period of 2012-02-01
# Waiting 2 seconds to retrieve year 2012 and month 3
# Captured bus ridership of 31467904 for the period of 2012-03-01
# Waiting 5 seconds to retrieve year 2012 and month 4
# Captured bus ridership of 29494708 for the period of 2012-04-01
# Waiting 4 seconds to retrieve year 2012 and month 5
# Captured bus ridership of 31768763 for the period of 2012-05-01
# Waiting 4 seconds to retrieve year 2012 and month 6
# Captured bus ridership of 29748939 for the period of 2012-06-01
# Waiting 5 seconds to retrieve year 2012 and month 7
# Captured bus ridership of 28908836 for the period of 2012-07-01
# Waiting 2 seconds to retrieve year 2012 and month 8
# Captured bus ridership of 31071556 for the period of 2012-08-01
# Waiting 5 seconds to retrieve year 2012 and month 9
# Captured bus ridership of 29750924 for the period of 2012-09-01
# Waiting 4 seconds to retrieve year 2012 and month 10
# Captured bus ridership of 32712793 for the period of 2012-10-01
# Waiting 5 seconds to retrieve year 2012 and month 11
# Captured bus ridership of 29046614 for the period of 2012-11-01
# Waiting 4 seconds to retrieve year 2012 and month 12
# Captured bus ridership of 27483168 for the period of 2012-12-01
# Waiting 2 seconds to retrieve year 2013 and month 1
# Captured bus ridership of 29386200 for the period of 2013-01-01
# Waiting 5 seconds to retrieve year 2013 and month 2
# Captured bus ridership of 28514044 for the period of 2013-02-01
# Waiting 4 seconds to retrieve year 2013 and month 3
# Captured bus ridership of 31025820 for the period of 2013-03-01
# Waiting 5 seconds to retrieve year 2013 and month 4
# Captured bus ridership of 31059181 for the period of 2013-04-01
# Waiting 4 seconds to retrieve year 2013 and month 5
# Captured bus ridership of 31723193 for the period of 2013-05-01
# Waiting 3 seconds to retrieve year 2013 and month 6
# Captured bus ridership of 28821701 for the period of 2013-06-01
# Waiting 4 seconds to retrieve year 2013 and month 7
# Captured bus ridership of 30019870 for the period of 2013-07-01
# Waiting 4 seconds to retrieve year 2013 and month 8
# Captured bus ridership of 31292483 for the period of 2013-08-01
# Waiting 5 seconds to retrieve year 2013 and month 9
# Captured bus ridership of 30481952 for the period of 2013-09-01
# Waiting 3 seconds to retrieve year 2013 and month 10
# Captured bus ridership of 32808584 for the period of 2013-10-01
# Waiting 4 seconds to retrieve year 2013 and month 11
# Captured bus ridership of 29182055 for the period of 2013-11-01
# Waiting 4 seconds to retrieve year 2013 and month 12
# Captured bus ridership of 29004415 for the period of 2013-12-01
# Waiting 5 seconds to retrieve year 2014 and month 1
# Captured bus ridership of 29748496 for the period of 2014-01-01
# Waiting 4 seconds to retrieve year 2014 and month 2
# Captured bus ridership of 28303852 for the period of 2014-02-01
# Waiting 4 seconds to retrieve year 2014 and month 3
# Captured bus ridership of 31150390 for the period of 2014-03-01
# Waiting 3 seconds to retrieve year 2014 and month 4
# Captured bus ridership of 30579856 for the period of 2014-04-01
# Waiting 4 seconds to retrieve year 2014 and month 5
# Captured bus ridership of 30936094 for the period of 2014-05-01
# Waiting 3 seconds to retrieve year 2014 and month 6
# Captured bus ridership of 27956197 for the period of 2014-06-01
# Waiting 5 seconds to retrieve year 2014 and month 7
# Captured bus ridership of 28698306 for the period of 2014-07-01
# Waiting 2 seconds to retrieve year 2014 and month 8
# Captured bus ridership of 29357120 for the period of 2014-08-01
# Waiting 4 seconds to retrieve year 2014 and month 9
# Captured bus ridership of 29222568 for the period of 2014-09-01
# Waiting 2 seconds to retrieve year 2014 and month 10
# Captured bus ridership of 31070146 for the period of 2014-10-01
# Waiting 4 seconds to retrieve year 2014 and month 11
# Captured bus ridership of 27574037 for the period of 2014-11-01
# Waiting 5 seconds to retrieve year 2014 and month 12
# Captured bus ridership of 27461076 for the period of 2014-12-01
# Waiting 2 seconds to retrieve year 2015 and month 1
# Captured bus ridership of 27674223 for the period of 2015-01-01
# Waiting 3 seconds to retrieve year 2015 and month 2
# Captured bus ridership of 27170544 for the period of 2015-02-01
# Waiting 3 seconds to retrieve year 2015 and month 3
# Captured bus ridership of 29892033 for the period of 2015-03-01
# Waiting 2 seconds to retrieve year 2015 and month 4
# Captured bus ridership of 28777494 for the period of 2015-04-01
# Waiting 4 seconds to retrieve year 2015 and month 5
# Captured bus ridership of 28283902 for the period of 2015-05-01
# Waiting 3 seconds to retrieve year 2015 and month 6
# Captured bus ridership of 27568238 for the period of 2015-06-01
# Waiting 4 seconds to retrieve year 2015 and month 7
# Captured bus ridership of 27796993 for the period of 2015-07-01
# Waiting 3 seconds to retrieve year 2015 and month 8
# Captured bus ridership of 27796274 for the period of 2015-08-01
# Waiting 5 seconds to retrieve year 2015 and month 9
# Captured bus ridership of 27988209 for the period of 2015-09-01
# Waiting 2 seconds to retrieve year 2015 and month 10
# Captured bus ridership of 29259504 for the period of 2015-10-01
# Waiting 2 seconds to retrieve year 2015 and month 11
# Captured bus ridership of 25969962 for the period of 2015-11-01
# Waiting 5 seconds to retrieve year 2015 and month 12
# Captured bus ridership of 25793811 for the period of 2015-12-01
# Waiting 4 seconds to retrieve year 2016 and month 1
# Captured bus ridership of 24664323 for the period of 2016-01-01
# Waiting 2 seconds to retrieve year 2016 and month 2
# Captured bus ridership of 26233143 for the period of 2016-02-01
# Waiting 3 seconds to retrieve year 2016 and month 3
# Captured bus ridership of 27402325 for the period of 2016-03-01
# Waiting 5 seconds to retrieve year 2016 and month 4
# Captured bus ridership of 26288443 for the period of 2016-04-01
# Waiting 2 seconds to retrieve year 2016 and month 5
# Captured bus ridership of 26326837 for the period of 2016-05-01
# Waiting 5 seconds to retrieve year 2016 and month 6
# Captured bus ridership of 25203232 for the period of 2016-06-01
# Waiting 3 seconds to retrieve year 2016 and month 7
# Captured bus ridership of 24277043 for the period of 2016-07-01
# Waiting 2 seconds to retrieve year 2016 and month 8
# Captured bus ridership of 25973842 for the period of 2016-08-01
# Waiting 5 seconds to retrieve year 2016 and month 9
# Captured bus ridership of 25455175 for the period of 2016-09-01
# Waiting 3 seconds to retrieve year 2016 and month 10
# Captured bus ridership of 25531633 for the period of 2016-10-01
# Waiting 2 seconds to retrieve year 2016 and month 11
# Captured bus ridership of 23979603 for the period of 2016-11-01
# Waiting 5 seconds to retrieve year 2016 and month 12
# Captured bus ridership of 22825258 for the period of 2016-12-01
# Waiting 4 seconds to retrieve year 2017 and month 1
# Captured bus ridership of 22171342 for the period of 2017-01-01
# Waiting 5 seconds to retrieve year 2017 and month 2
# Captured bus ridership of 21604148 for the period of 2017-02-01
# Waiting 2 seconds to retrieve year 2017 and month 3
# Captured bus ridership of 25794248 for the period of 2017-03-01
# Waiting 2 seconds to retrieve year 2017 and month 4
# Captured bus ridership of 23611510 for the period of 2017-04-01
# Waiting 2 seconds to retrieve year 2017 and month 5
# Captured bus ridership of 25086327 for the period of 2017-05-01
# Waiting 5 seconds to retrieve year 2017 and month 6
# Captured bus ridership of 23716670 for the period of 2017-06-01
# Waiting 5 seconds to retrieve year 2017 and month 7
# Captured bus ridership of 22942241 for the period of 2017-07-01
# Waiting 3 seconds to retrieve year 2017 and month 8
# Captured bus ridership of 24861705 for the period of 2017-08-01
# Waiting 5 seconds to retrieve year 2017 and month 9
# Captured bus ridership of 24113300 for the period of 2017-09-01
# Waiting 4 seconds to retrieve year 2017 and month 10
# Captured bus ridership of 25331595 for the period of 2017-10-01
# Waiting 2 seconds to retrieve year 2017 and month 11
# Captured bus ridership of 23298641 for the period of 2017-11-01
# Waiting 3 seconds to retrieve year 2017 and month 12
# Captured bus ridership of 22176563 for the period of 2017-12-01
# Waiting 5 seconds to retrieve year 2018 and month 1
# Captured bus ridership of 22675482 for the period of 2018-01-01
# Waiting 2 seconds to retrieve year 2018 and month 2
# Captured bus ridership of 21958972 for the period of 2018-02-01
# Waiting 3 seconds to retrieve year 2018 and month 3
# Captured bus ridership of 23214316 for the period of 2018-03-01
# Waiting 3 seconds to retrieve year 2018 and month 4
# Captured bus ridership of 23331877 for the period of 2018-04-01
# Waiting 4 seconds to retrieve year 2018 and month 5
# Captured bus ridership of 24198091 for the period of 2018-05-01
# Waiting 2 seconds to retrieve year 2018 and month 6
# Captured bus ridership of 22691252 for the period of 2018-06-01
# Waiting 3 seconds to retrieve year 2018 and month 7
# Captured bus ridership of 22105750 for the period of 2018-07-01
# Waiting 5 seconds to retrieve year 2018 and month 8
# Captured bus ridership of 24128752 for the period of 2018-08-01
# Waiting 4 seconds to retrieve year 2018 and month 9
# Captured bus ridership of 22965413 for the period of 2018-09-01
# Waiting 5 seconds to retrieve year 2018 and month 10
# Captured bus ridership of 25080291 for the period of 2018-10-01
# Waiting 2 seconds to retrieve year 2018 and month 11
# Captured bus ridership of 22438608 for the period of 2018-11-01
# Waiting 5 seconds to retrieve year 2018 and month 12
# Captured bus ridership of 20988857 for the period of 2018-12-01
# Waiting 2 seconds to retrieve year 2019 and month 1
# Captured bus ridership of 21263765 for the period of 2019-01-01
# Waiting 2 seconds to retrieve year 2019 and month 2
# Captured bus ridership of 20883716 for the period of 2019-02-01
# Waiting 5 seconds to retrieve year 2019 and month 3
# Captured bus ridership of 23562034 for the period of 2019-03-01
# Waiting 2 seconds to retrieve year 2019 and month 4
# Captured bus ridership of 23691650 for the period of 2019-04-01
# Waiting 2 seconds to retrieve year 2019 and month 5
# Captured bus ridership of 24351954 for the period of 2019-05-01
# Waiting 3 seconds to retrieve year 2019 and month 6
# Captured bus ridership of 22286620 for the period of 2019-06-01
# Waiting 5 seconds to retrieve year 2019 and month 7
# Captured bus ridership of 23735873 for the period of 2019-07-01
# Waiting 4 seconds to retrieve year 2019 and month 8
# Captured bus ridership of 24649209 for the period of 2019-08-01
# Waiting 3 seconds to retrieve year 2019 and month 9
# Captured bus ridership of 24102718 for the period of 2019-09-01
# Waiting 2 seconds to retrieve year 2019 and month 10
# Captured bus ridership of 26065766 for the period of 2019-10-01
# Waiting 3 seconds to retrieve year 2019 and month 11
# Captured bus ridership of 21760680 for the period of 2019-11-01
# Waiting 4 seconds to retrieve year 2019 and month 12
# Captured bus ridership of 20954860 for the period of 2019-12-01
# Waiting 4 seconds to retrieve year 2020 and month 1
# Captured bus ridership of 21987685 for the period of 2020-01-01
# Waiting 4 seconds to retrieve year 2020 and month 2
# Captured bus ridership of 21767867 for the period of 2020-02-01
# Waiting 4 seconds to retrieve year 2020 and month 3
# Captured bus ridership of 15323805 for the period of 2020-03-01
# Waiting 2 seconds to retrieve year 2020 and month 4
# Captured bus ridership of 7448380 for the period of 2020-04-01
# Waiting 3 seconds to retrieve year 2020 and month 5
# Captured bus ridership of 9096081 for the period of 2020-05-01
# Waiting 2 seconds to retrieve year 2020 and month 6
# Captured bus ridership of 10679063 for the period of 2020-06-01

# %%
home_page_browser.quit()

# %%
if (notifyStatus): status_notify("Task 2 Perform the Scraping and Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Task 3. Finalize the Output

# %%
if (notifyStatus): status_notify("Task 3 Finalize the Output has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Spot-checking the dataframe before writing to file
df.head()
# Out:
#           idx    values
# 0  2009-01-01  30580085
# 1  2009-02-01  28778916
# 2  2009-03-01  32963302
# 3  2009-04-01  31471512
# 4  2009-05-01  31665879

# %%
# Spot-checking the dataframe before writing to file
df.tail()
# Out:
#             idx    values
# 133  2020-02-01  21767867
# 134  2020-03-01  15323805
# 135  2020-04-01   7448380
# 136  2020-05-01   9096081
# 137  2020-06-01  10679063

# %%
if (writeOutput):
    out_file = df.to_csv(index=False)
    with open('web_scraping_py_selenium_metro_ridership_statistics.csv', 'w', newline = '\n') as f:
        f.write(out_file)
    print("Number of records written to file:", len(df))
# Out:
# Number of records written to file: 138

# %%
if (notifyStatus): status_notify("Task 3 Finalize the Output completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:09:33.272139
