# %% [markdown]
# # Web Scraping of AWS re:Invent 2019 Using Python and BeautifulSoup
# ### David Lowe
# ### January 10, 2020
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific pieces of information from a website. The web scraping Python code leverages the BeautifulSoup module.
#
# INTRODUCTION: The AWS re:Invent is a learning conference featuring keynote announcements, training and certification opportunities, a partner expo, and access to more than 2,500 technical sessions. This web scraping script will automatically traverse through the entire web page and collect all links to the PDF and PPTX documents. The script will also download the documents as part of the scraping process.
#
# Starting URLs: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent

# %% [markdown]
# ## Section 0. Prepare Environment

# %%
# Colab-Specific Setup - Refresh Linux package repositories and set up additional Linux and Python tools
# !apt-get update
# !apt install chromium-chromedriver
# !pip install -q pymysql selenium

# %%
import numpy as np
import pandas as pd
import os
import shutil
import smtplib
import sys
from email.message import EmailMessage
from datetime import datetime
import requests
from requests.exceptions import HTTPError
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
from random import randint
from time import sleep
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose and debug flags to print detailed messages for debugging (setting True will activate!)
verbose = False
debug = False

# Set up the flag to send status emails (setting to True will send the status emails!)
notifyStatus = False

# Set up the mountStorage flag to mount G Drive for storing files (setting True will mount the drive!)
mountStorage = False

# Set up the executeDownload flag to download files (setting True will download!)
executeDownload = True

# %%
# Colab-Specific Setup - Mount Google Drive for storing downloaded files
if (mountStorage):
    from google.colab import drive
    drive.mount('/content/gdrive')

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Web Scraping Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
def access_url(url):
    wait_time = 10
    firefox_options = Options()
    firefox_options.headless = True
    print('Attempting to access the web page: ' + url)
    browser = webdriver.Firefox(options=firefox_options)
    browser.get(url)
    sleep(wait_time)
    innerHTML = browser.execute_script("return document.body.innerHTML")
    sleep(wait_time)
    bsoup_obj = BeautifulSoup(innerHTML, 'lxml')
    if (debug): print(bsoup_obj.prettify())
    browser.quit()
    return bsoup_obj

# %%
def download_to_local(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    if (os.path.isfile(local_file) == False):
        with requests.get(doc_path, stream=True) as r:
            with open(local_file, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print('Downladed file: ' + local_file)
    else:
        print('Skipped existing file: ' + local_file)

# %%
def download_to_gdrive(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
    dest_file = gdrivePrefix + local_file
    with requests.get(doc_path, stream=True) as r:
        with open(dest_file, 'wb') as f:
            shutil.copyfileobj(r.raw, f)
    print('Downladed file: ' + dest_file)

# %%
if (notifyStatus): email_notify("Phase 0 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 1. Perform the Scraping and Processing

# %%
if (notifyStatus): email_notify("Phase 1 Perform the Scraping and Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Specifying the URL of desired web page to be scrapped
website_url = "https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards="
card_number = 1
max_card = 117
starting_url = website_url + str(card_number)

# %%
i = 0
while (card_number <= max_card):
    card_url = website_url + str(card_number)
    web_page = access_url(card_url)
    # Gather all links to the document
    collection = web_page.find_all('h2', class_='m-headline')
    for item in collection:
        if (verbose): print('Found item:', item)
        doc_link = item.a
        doc_path = doc_link['href']
        if doc_path.lower().endswith(".pdf") | doc_path.lower().endswith(".pptx") | doc_path.lower().endswith(".zip"):
            i = i + 1
            if (executeDownload): download_to_local(doc_path)
    card_number = card_number + 1

print('Finished finding all available documents on the web pages!')
print('Total presentation documents downloaded:', i)
# Out:
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=1
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/AWS_China_Gateway_Power_your_business_in_China_by_working_with_AWS_CHN202.pdf
# Downladed file: AWS_China_Gateway_Power_your_business_in_China_by_working_with_AWS_CHN202.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Performance_tune_SQL_Server_using_AWS_Machine_Learning_WIN407-R1.pdf
# Downladed file: REPEAT_1_Performance_tune_SQL_Server_using_AWS_Machine_Learning_WIN407-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_multi-region_SQL_Server_Always_On_availability_groups_WIN406-R1.pdf
# Downladed file: REPEAT_1_Build_multi-region_SQL_Server_Always_On_availability_groups_WIN406-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Active_Directory_design_patterns_on_AWS_WIN405-R1.pdf
# Downladed file: REPEAT_1_Active_Directory_design_patterns_on_AWS_WIN405-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Managing_the_health_of_.NET_apps_and_SQL_Server_on_AWS_WIN404-R1.pdf
# Downladed file: REPEAT_1_Managing_the_health_of_.NET_apps_and_SQL_Server_on_AWS_WIN404-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_for_.NET_Core_connection_pooling_in_serverless_apps_WIN403-R1.pdf
# Downladed file: REPEAT_1_Best_practices_for_.NET_Core_connection_pooling_in_serverless_apps_WIN403-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Modernize_your_SQL_Server_workloads_to_Amazon_Aurora_WIN401-R1.pdf
# Downladed file: REPEAT_1_Modernize_your_SQL_Server_workloads_to_Amazon_Aurora_WIN401-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Migrating_Azure_VMs_to_AWS_using_AWS_SMS_and_CloudEndure_WIN323-R1.pdf
# Downladed file: REPEAT_1_Migrating_Azure_VMs_to_AWS_using_AWS_SMS_and_CloudEndure_WIN323-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Leverage_automation_to_re-platform_SQL_Server_to_Linux_WIN322-R1.pdf
# Downladed file: REPEAT_1_Leverage_automation_to_re-platform_SQL_Server_to_Linux_WIN322-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Improving_Windows_instance_start_times_WIN321-R1.pdf
# Downladed file: REPEAT_1_Improving_Windows_instance_start_times_WIN321-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Automating_the_upgrade_of_Amazon_EC2_Windows_instances_WIN320-R1.pdf
# Downladed file: REPEAT_1_Automating_the_upgrade_of_Amazon_EC2_Windows_instances_WIN320-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_for_advanced_SQL_Server_storage_architectures_WIN319-R1.pdf
# Downladed file: REPEAT_1_Best_practices_for_advanced_SQL_Server_storage_architectures_WIN319-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=2
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_Best_practices_for_advanced_SQL_Server_storage_architectures_WIN319-R.pdf
# Downladed file: REPEAT_Best_practices_for_advanced_SQL_Server_storage_architectures_WIN319-R.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Manage_your_Microsoft_licenses_on-premises_and_in_the_cloud_WIN318-R2.pdf
# Downladed file: REPEAT_2_Manage_your_Microsoft_licenses_on-premises_and_in_the_cloud_WIN318-R2.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Demystifying_identity,_AuthN,_and_AuthZ_for_.NET_apps_on_AWS_WIN317.pdf
# Downladed file: Demystifying_identity,_AuthN,_and_AuthZ_for_.NET_apps_on_AWS_WIN317.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Building_AWS_IoT_applications_using_.NET_WIN316.pdf
# Downladed file: Building_AWS_IoT_applications_using_.NET_WIN316.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Converting_a_monolithic_.NET_app_into_a_modern_application_WIN315-R1.pdf
# Downladed file: REPEAT_1_Converting_a_monolithic_.NET_app_into_a_modern_application_WIN315-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Best_practices_for_.NET_DevOps_on_AWS_WIN314.pdf
# Downladed file: Best_practices_for_.NET_DevOps_on_AWS_WIN314.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Design,_migrate,_and_optimize_SQL_Server_on_AWS_WIN313-R1.pdf
# Downladed file: REPEAT_1_Design,_migrate,_and_optimize_SQL_Server_on_AWS_WIN313-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Infrastructure_as_.NET_with_the_AWS_CDK_WIN310.pdf
# Downladed file: Infrastructure_as_.NET_with_the_AWS_CDK_WIN310.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Containerize_.NET_Apps_with_Amazon_EKS_and_AWS_Fargate_WIN309.pdf
# Downladed file: Containerize_.NET_Apps_with_Amazon_EKS_and_AWS_Fargate_WIN309.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Developing_serverless_.NET_Core_on_AWS_WIN308-R1.pdf
# Downladed file: REPEAT_1_Developing_serverless_.NET_Core_on_AWS_WIN308-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Manage_Windows_instances_at_scale_with_Systems_Manager_WIN307.pdf
# Downladed file: Manage_Windows_instances_at_scale_with_Systems_Manager_WIN307.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Migrate_Microsoft_workloads_to_AWS_WIN306.pdf
# Downladed file: Migrate_Microsoft_workloads_to_AWS_WIN306.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=3
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Modernize_legacy_.NET_applications_on_AWS_WIN304-R1.pdf
# Downladed file: REPEAT_1_Modernize_legacy_.NET_applications_on_AWS_WIN304-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Deploy_modern_apps_with_the_AWS_Cloud_Development_Kit_for_.NET_Core_WIN303.pdf
# Downladed file: Deploy_modern_apps_with_the_AWS_Cloud_Development_Kit_for_.NET_Core_WIN303.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Migrating_Microsoft_applications_to_AWS_like_an_expert_WIN302.pdf
# Downladed file: Migrating_Microsoft_applications_to_AWS_like_an_expert_WIN302.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Modernizing_Microsoft_SQL_Server_on_AWS_WIN301-R1.pdf
# Downladed file: REPEAT_1_Modernizing_Microsoft_SQL_Server_on_AWS_WIN301-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Everything_you_need_to_know_about_Amazon_FSx_for_Windows_File_Server_WIN204-R1.pdf
# Downladed file: REPEAT_1_Everything_you_need_to_know_about_Amazon_FSx_for_Windows_File_Server_WIN204-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Addressing__questions_around_Microsoft_end_of_support_(EOS)_WIN203-R1.pdf
# Downladed file: REPEAT_1_Addressing__questions_around_Microsoft_end_of_support_(EOS)_WIN203-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_How_to_cost-optimize_your_Microsoft_workloads_on_AWS_WIN202-R1.pdf
# Downladed file: REPEAT_1_How_to_cost-optimize_your_Microsoft_workloads_on_AWS_WIN202-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/We_Power_Tech_Women_shifting_to_an_abundance_mindset_WPT204.pdf
# Downladed file: We_Power_Tech_Women_shifting_to_an_abundance_mindset_WPT204.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/We_Power_Tech_Promoting_fairness_in_AIML_WPT202.pdf
# Downladed file: We_Power_Tech_Promoting_fairness_in_AIML_WPT202.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Turn_Travel_and_Hospitality_call_centers_into_profit_centers_TRH302.pdf
# Downladed file: Turn_Travel_and_Hospitality_call_centers_into_profit_centers_TRH302.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Unlocking_the_potential_of_IoT_in_Travel_and_Hospitality_TRH301.pdf
# Downladed file: Unlocking_the_potential_of_IoT_in_Travel_and_Hospitality_TRH301.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Personalizing_customer_experiences_in_Travel_and_Hospitality_TRH202.pdf
# Downladed file: Personalizing_customer_experiences_in_Travel_and_Hospitality_TRH202.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=4
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Leadership_session_Travel_and_Hospitality_TRH201-L.pdf
# Downladed file: Leadership_session_Travel_and_Hospitality_TRH201-L.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Industry_4.0_with_mobile_edge_network_services_powered_by_AWS_Outposts_TLC305.pdf
# Downladed file: Industry_4.0_with_mobile_edge_network_services_powered_by_AWS_Outposts_TLC305.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_Vodafone's_Intelligent_Care_platform_utilizes_AWS_TLC303.pdf
# Downladed file: How_Vodafone's_Intelligent_Care_platform_utilizes_AWS_TLC303.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Securely_scale_your_VoIP_with_Amazon_Chime_&_Ribbon_TLC302.pdf
# Downladed file: Securely_scale_your_VoIP_with_Amazon_Chime_&_Ribbon_TLC302.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/AI-driven_self-healing,_churn_prediction,_and_fraud_detection_on_AWS_TLC301.pdf
# Downladed file: AI-driven_self-healing,_churn_prediction,_and_fraud_detection_on_AWS_TLC301.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Leadership_session_Join_T-Mobile_in_a_rapid_cloud-native_journey_TLC205-L.pdf
# Downladed file: Leadership_session_Join_T-Mobile_in_a_rapid_cloud-native_journey_TLC205-L.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Implementing_telecommunication_data_analytics_TLC204-R1.pdf
# Downladed file: REPEAT_1_Implementing_telecommunication_data_analytics_TLC204-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/From_SMS_to_5G_Out-of-the-box_telecom_solution_TLC203.pdf
# Downladed file: From_SMS_to_5G_Out-of-the-box_telecom_solution_TLC203.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Assurance_Cloud_Telco-grade_assurance_via_the_cloud_with_MYCOM_&_AWS_TLC202.pdf
# Downladed file: Assurance_Cloud_Telco-grade_assurance_via_the_cloud_with_MYCOM_&_AWS_TLC202.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Maximizing_Amazon_EFS_performance_for_Linux_workloads_STG405.pdf
# Downladed file: Maximizing_Amazon_EFS_performance_for_Linux_workloads_STG405.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Architecting_hybrid_cloud_media_workflows_STG404.pdf
# Downladed file: Architecting_hybrid_cloud_media_workflows_STG404.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Querying_data_in_place_with_Amazon_S3_and_analytics_tools_STG402.pdf
# Downladed file: Querying_data_in_place_with_Amazon_S3_and_analytics_tools_STG402.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=5
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Manage_objects_and_optimize_cost_with_Amazon_S3_and_Amazon_S3_Glacier_STG401.pdf
# Downladed file: Manage_objects_and_optimize_cost_with_Amazon_S3_and_Amazon_S3_Glacier_STG401.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Self-service_disaster_recovery_for_AWS_with_Druva_STG365-S.pdf
# Downladed file: Self-service_disaster_recovery_for_AWS_with_Druva_STG365-S.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Securing_Amazon_EFS_for_container_and_data_science_applications_STG364.pdf
# Downladed file: Securing_Amazon_EFS_for_container_and_data_science_applications_STG364.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Managing_access_to_Amazon_S3_buckets_at_scale_STG363-R2.pdf
# Downladed file: REPEAT_2_Managing_access_to_Amazon_S3_buckets_at_scale_STG363-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Migrating_Windows_file_servers_to_Amazon_FSx_STG362-R2.pdf
# Downladed file: REPEAT_2_Migrating_Windows_file_servers_to_Amazon_FSx_STG362-R2.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_for_implementing_a_data_lake_on_Amazon_S3_ft._AppsFlyer_STG359-R1.pdf
# Downladed file: REPEAT_1_Best_practices_for_implementing_a_data_lake_on_Amazon_S3_ft._AppsFlyer_STG359-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_Best_practices_for_implementing_a_data_lake_on_Amazon_S3_ft._Sweetgreen_STG359-R.pdf
# Downladed file: REPEAT_Best_practices_for_implementing_a_data_lake_on_Amazon_S3_ft._Sweetgreen_STG359-R.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Configuration_and_management_with_Amazon_S3_STG358-R1.pdf
# Downladed file: REPEAT_1_Configuration_and_management_with_Amazon_S3_STG358-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Best_practices_to_optimize_costs_for_Amazon_S3_STG357.pdf
# Downladed file: Best_practices_to_optimize_costs_for_Amazon_S3_STG357.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Managing_access_to_Amazon_S3_buckets_STG356.pdf
# Downladed file: Managing_access_to_Amazon_S3_buckets_STG356.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Archiving_media_content_with_Amazon_S3_Glacier_Deep_Archive_STG355.pdf
# Downladed file: Archiving_media_content_with_Amazon_S3_Glacier_Deep_Archive_STG355.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Large-scale_file_migrations_with_AWS_DataSync_STG354.pdf
# Downladed file: Large-scale_file_migrations_with_AWS_DataSync_STG354.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=6
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Edge_computing,_IoT_&_machine_learning_in_disaster_response_STG353.pdf
# Downladed file: Edge_computing,_IoT_&_machine_learning_in_disaster_response_STG353.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Edge_computing_in_disaster_response_with_Snowball_Edge_STG352.pdf
# Downladed file: Edge_computing_in_disaster_response_with_Snowball_Edge_STG352.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Meeting_performance_needs_for_database_workloads_on_Amazon_EBS_STG351.pdf
# Downladed file: Meeting_performance_needs_for_database_workloads_on_Amazon_EBS_STG351.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Securing_your_block_storage_on_AWS_STG350.pdf
# Downladed file: Securing_your_block_storage_on_AWS_STG350.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Optimize_video_processing_using_Amazon_FSx_for_Lustre_STG349.pdf
# Downladed file: Optimize_video_processing_using_Amazon_FSx_for_Lustre_STG349.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Optimize_HPC_workload_storage_using_Amazon_FSx_for_Lustre_STG348.pdf
# Downladed file: Optimize_HPC_workload_storage_using_Amazon_FSx_for_Lustre_STG348.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Choosing_the_right_storage_for_your_high-performance_workloads_STG347.pdf
# Downladed file: Choosing_the_right_storage_for_your_high-performance_workloads_STG347.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Deep_dive_on_CloudEndure_Disaster_Recovery_STG346-R1.pdf
# Downladed file: REPEAT_1_Deep_dive_on_CloudEndure_Disaster_Recovery_STG346-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Optimize_your_storage_performance_with_Amazon_S3,_ft._Lyft_STG343.pdf
# Downladed file: Optimize_your_storage_performance_with_Amazon_S3,_ft._Lyft_STG343.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Rapid_online_data_transfer_with_AWS_DataSync_STG342.pdf
# Downladed file: Rapid_online_data_transfer_with_AWS_DataSync_STG342.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Deep_dive_on_AWS_Backup,_ft._Rackspace_STG341.pdf
# Downladed file: Deep_dive_on_AWS_Backup,_ft._Rackspace_STG341.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/What_to_consider_when_building_a_data_lake_on_Amazon_S3_STG340.pdf
# Downladed file: What_to_consider_when_building_a_data_lake_on_Amazon_S3_STG340.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=7
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Managing_Amazon_S3_and_Amazon_S3_Glacier_objects_at_scale_STG339-R1.pdf
# Downladed file: REPEAT_1_Managing_Amazon_S3_and_Amazon_S3_Glacier_objects_at_scale_STG339-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Ask_me_anything_about_Amazon_S3_STG338-R1.pdf
# Downladed file: REPEAT_1_Ask_me_anything_about_Amazon_S3_STG338-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Managing_large-scale_offline_data_migrations_Best_practices_STG337.pdf
# Downladed file: Managing_large-scale_offline_data_migrations_Best_practices_STG337.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Using_hybrid_cloud_storage_to_close_a_data_center_and_migrate_STG336.pdf
# Downladed file: Using_hybrid_cloud_storage_to_close_a_data_center_and_migrate_STG336.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Reduce_TCO_for_your_file-based_applications_STG335-R1.pdf
# Downladed file: REPEAT_1_Reduce_TCO_for_your_file-based_applications_STG335-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Optimizing_performance_on_Amazon_S3_STG334-R1.pdf
# Downladed file: REPEAT_1_Optimizing_performance_on_Amazon_S3_STG334-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Migrate_and_modernize_SFTP_file_transfer_workflows_with_AWS_STG333.pdf
# Downladed file: Migrate_and_modernize_SFTP_file_transfer_workflows_with_AWS_STG333.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Beyond_eleven_nines_Lessons_from_the_Amazon_S3_culture_of_durability_STG331-R1.pdf
# Downladed file: REPEAT_1_Beyond_eleven_nines_Lessons_from_the_Amazon_S3_culture_of_durability_STG331-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Tech_deep_dive_Backup_&_on-demand_disaster_recovery_with_Veeam_and_AWS_STG330-S.pdf
# Downladed file: Tech_deep_dive_Backup_&_on-demand_disaster_recovery_with_Veeam_and_AWS_STG330-S.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Maximizing_storage_throughput_and_performance_STG329-R1.pdf
# Downladed file: REPEAT_1_Maximizing_storage_throughput_and_performance_STG329-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Build_a_simple_trade-reconciliation_platform_with_AWS_services_STG328.pdf
# Downladed file: Build_a_simple_trade-reconciliation_platform_with_AWS_services_STG328.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Set_up_a_disaster-recovery_project_with_CloudEndure_Disaster_Recovery_STG327.pdf
# Downladed file: Set_up_a_disaster-recovery_project_with_CloudEndure_Disaster_Recovery_STG327.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=8
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Deploy_fully_managed_FSx_for_Windows_File_Server_instances_in_minutes_STG326.pdf
# Downladed file: Deploy_fully_managed_FSx_for_Windows_File_Server_instances_in_minutes_STG326.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Map_and_drive_performance_with_Amazon_FSx_for_Windows_File_Server_STG324.pdf
# Downladed file: Map_and_drive_performance_with_Amazon_FSx_for_Windows_File_Server_STG324.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Amazon_FSx_for_Lustre_High-performance_file_system_with_Amazon_S3_STG323-R1.pdf
# Downladed file: REPEAT_1_Amazon_FSx_for_Lustre_High-performance_file_system_with_Amazon_S3_STG323-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Secure_data_in_Amazon_S3_and_Amazon_S3_Glacier_STG322-R2.pdf
# Downladed file: REPEAT_2_Secure_data_in_Amazon_S3_and_Amazon_S3_Glacier_STG322-R2.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Get_hands-on_&_learn_best_practices_for_AWS_data_migrations_STG316.pdf
# Downladed file: Get_hands-on_&_learn_best_practices_for_AWS_data_migrations_STG316.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Amazon_S3_security_settings_and_controls_STG315-R1.pdf
# Downladed file: REPEAT_1_Amazon_S3_security_settings_and_controls_STG315-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Hybrid_architectures_for_database_backups_&_file_migrations_STG313-R1.pdf
# Downladed file: REPEAT_1_Hybrid_architectures_for_database_backups_&_file_migrations_STG313-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Modernize_your_applications_with_containers_using_Amazon_EFS_STG312.pdf
# Downladed file: Modernize_your_applications_with_containers_using_Amazon_EFS_STG312.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Edge_computing_use_cases_Deep_dive_on_AWS_Snowball_Edge_STG310-R1.pdf
# Downladed file: REPEAT_1_Edge_computing_use_cases_Deep_dive_on_AWS_Snowball_Edge_STG310-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Deep_dive_on_security_in_Amazon_S3_and_Amazon_S3_Glacier_STG308-R1.pdf
# Downladed file: REPEAT_1_Deep_dive_on_security_in_Amazon_S3_and_Amazon_S3_Glacier_STG308-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Amazon_S3_&_FSx_for_Lustre_Deep_dive_on_high-performance_file_storage_STG307-R1.pdf
# Downladed file: REPEAT_1_Amazon_S3_&_FSx_for_Lustre_Deep_dive_on_high-performance_file_storage_STG307-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Deep_dive_on_Amazon_FSx_for_Windows_File_Server_STG306-R1.pdf
# Downladed file: REPEAT_1_Deep_dive_on_Amazon_FSx_for_Windows_File_Server_STG306-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=9
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_hybrid_storage_architectures_with_AWS_Storage_Gateway_STG305-R1.pdf
# Downladed file: REPEAT_1_Build_hybrid_storage_architectures_with_AWS_Storage_Gateway_STG305-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_Build_hybrid_storage_architectures_with_AWS_Storage_Gateway_STG305-R.pdf
# Downladed file: REPEAT_Build_hybrid_storage_architectures_with_AWS_Storage_Gateway_STG305-R.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Network_file_system_(NFS)_evolved_Deep_dive_on_Amazon_EFS_STG304-R1.pdf
# Downladed file: REPEAT_1_Network_file_system_(NFS)_evolved_Deep_dive_on_Amazon_EFS_STG304-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Deep_dive_on_Amazon_EBS_STG303-R1.pdf
# Downladed file: REPEAT_1_Deep_dive_on_Amazon_EBS_STG303-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Best_practices_for_Amazon_S3_(including_storage_classes),_ft._Thomson_Reuters_STG302-R2.pdf
# Downladed file: REPEAT_2_Best_practices_for_Amazon_S3_(including_storage_classes),_ft._Thomson_Reuters_STG302-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_for_Amazon_S3_(including_storage_classes)_ft._Instructure_STG302-R1.pdf
# Downladed file: REPEAT_1_Best_practices_for_Amazon_S3_(including_storage_classes)_ft._Instructure_STG302-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_Best_practices_for_Amazon_S3_(including_storage_classes)_STG302-R.pdf
# Downladed file: REPEAT_Best_practices_for_Amazon_S3_(including_storage_classes)_STG302-R.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_3_Deep_dive_on_Amazon_S3_security_and_management_STG301-R3.pdf
# Downladed file: REPEAT_3_Deep_dive_on_Amazon_S3_security_and_management_STG301-R3.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Intuit_delivers_cloud_services_to_drive_customer_satisfaction_STG239-S.pdf
# Downladed file: Intuit_delivers_cloud_services_to_drive_customer_satisfaction_STG239-S.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Deep_dive_File_storage_for_business-critical_applications_STG238.pdf
# Downladed file: Deep_dive_File_storage_for_business-critical_applications_STG238.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Learn_how_GMI_achieves_high_performance_for_its_databases_STG237-S.pdf
# Downladed file: Learn_how_GMI_achieves_high_performance_for_its_databases_STG237-S.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Ensure_AWS_data_recoverability,_featuring_MassMutual_&_Boston_Scientific_STG236-S.pdf
# Downladed file: Ensure_AWS_data_recoverability,_featuring_MassMutual_&_Boston_Scientific_STG236-S.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=10
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Creating_and_running_your_first_job_in_Amazon_S3_batch_operations_STG230-R2.pdf
# Downladed file: REPEAT_2_Creating_and_running_your_first_job_in_Amazon_S3_batch_operations_STG230-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Optimizing_Amazon_S3_data_throughputs,_requests,_and_transfers_STG229-R1.pdf
# Downladed file: REPEAT_1_Optimizing_Amazon_S3_data_throughputs,_requests,_and_transfers_STG229-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2__Getting_started_with_hybrid_file_storage_using_File_Gateway_STG225-R2.pdf
# Downladed file: REPEAT_2__Getting_started_with_hybrid_file_storage_using_File_Gateway_STG225-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Developing_a_game_plan_for_storage_migration_to_AWS_STG222-R1.pdf
# Downladed file: REPEAT_1_Developing_a_game_plan_for_storage_migration_to_AWS_STG222-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/SFTP_workflows_for_data_lakes_and_enterprise_applications_STG221.pdf
# Downladed file: SFTP_workflows_for_data_lakes_and_enterprise_applications_STG221.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_to_move_700_TB_over_the_wire_to_AWS_with_AWS_DataSync_STG220.pdf
# Downladed file: How_to_move_700_TB_over_the_wire_to_AWS_with_AWS_DataSync_STG220.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Shift_your_tape_backups_to_AWS_to_save_time_and_money_STG217.pdf
# Downladed file: Shift_your_tape_backups_to_AWS_to_save_time_and_money_STG217.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Data_migration_and_edge_computing_with_the_AWS_Snow_family_STG214.pdf
# Downladed file: Data_migration_and_edge_computing_with_the_AWS_Snow_family_STG214.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Storage_for_hybrid_cloud_and_edge_computing_Bring_AWS_to_you_STG213.pdf
# Downladed file: Storage_for_hybrid_cloud_and_edge_computing_Bring_AWS_to_you_STG213.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Managing_your_data_at_scale_with_Amazon_S3_storage_management_tools_STG212.pdf
# Downladed file: Managing_your_data_at_scale_with_Amazon_S3_storage_management_tools_STG212.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_to_use_AWS_storage_for_on-premises_file-based_applications_STG211.pdf
# Downladed file: How_to_use_AWS_storage_for_on-premises_file-based_applications_STG211.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Real-world_Veeam_backup_and_disaster_recovery_with_AWS_A_customer_view_STG210-S.pdf
# Downladed file: Real-world_Veeam_backup_and_disaster_recovery_with_AWS_A_customer_view_STG210-S.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=11
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Backup-and-restore_and_disaster-recovery_solutions_with_AWS_STG208.pdf
# Downladed file: Backup-and-restore_and_disaster-recovery_solutions_with_AWS_STG208.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Five_hybrid_cloud_backup_and_disaster_recovery_mistakes_to_avoid_STG207-S.pdf
# Downladed file: Five_hybrid_cloud_backup_and_disaster_recovery_mistakes_to_avoid_STG207-S.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Stop_managing_SFTP_servers_today_STG206-R1.pdf
# Downladed file: REPEAT_1_Stop_managing_SFTP_servers_today_STG206-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Data_migration_Understanding_the_technologies_and_options_STG205-R2.pdf
# Downladed file: REPEAT_2_Data_migration_Understanding_the_technologies_and_options_STG205-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Get_your_data_to_AWS_How_to_choose_and_use_data_migration_services_STG204-R1.pdf
# Downladed file: REPEAT_1_Get_your_data_to_AWS_How_to_choose_and_use_data_migration_services_STG204-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_What's_new_with_Amazon_S3_and_Amazon_S3_Glacier_STG203-R2.pdf
# Downladed file: REPEAT_2_What's_new_with_Amazon_S3_and_Amazon_S3_Glacier_STG203-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/What's_new_in_AWS_file_storage_STG202.pdf
# Downladed file: What's_new_in_AWS_file_storage_STG202.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Leadership_session_Storage_state_of_the_union_STG201-L.pdf
# Downladed file: Leadership_session_Storage_state_of_the_union_STG201-L.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Predicting_what_your_customers_really,_really_want_STP304-R1.pdf
# Downladed file: REPEAT_1_Predicting_what_your_customers_really,_really_want_STP304-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Reduce_churn_using_machine_learning_STP303-R1.pdf
# Downladed file: REPEAT_1_Reduce_churn_using_machine_learning_STP303-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Using_Amazon_EMR_to_build_a_Spark_ecosystem_at_Opendoor_STP302.pdf
# Downladed file: Using_Amazon_EMR_to_build_a_Spark_ecosystem_at_Opendoor_STP302.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Personal_Capital_Lessons_from_a_year_with_Amazon_EKS_STP301.pdf
# Downladed file: Personal_Capital_Lessons_from_a_year_with_Amazon_EKS_STP301.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=12
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Quantifying_what_makes_your_happiest_customers_so_happy_STP209-R1.pdf
# Downladed file: REPEAT_1_Quantifying_what_makes_your_happiest_customers_so_happy_STP209-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_to_build_a_company_founded_on_engineering_principles_STP208.pdf
# Downladed file: How_to_build_a_company_founded_on_engineering_principles_STP208.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_Coinbase_handles_incident_management_by_leveraging_AWS_STP207.pdf
# Downladed file: How_Coinbase_handles_incident_management_by_leveraging_AWS_STP207.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Building_the_future_of_writing_with_AWS_Lambda_STP206.pdf
# Downladed file: Building_the_future_of_writing_with_AWS_Lambda_STP206.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_Affirm_leverages_AWS_to_support_a_unified_data_lake_STP205.pdf
# Downladed file: How_Affirm_leverages_AWS_to_support_a_unified_data_lake_STP205.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_Ginkgo_Bioworks_uses_AWS_to_make_organisms_STP201.pdf
# Downladed file: How_Ginkgo_Bioworks_uses_AWS_to_make_organisms_STP201.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Architecting_and_operating_resilient_serverless_systems_at_scale_SVS407-R2.pdf
# Downladed file: REPEAT_2_Architecting_and_operating_resilient_serverless_systems_at_scale_SVS407-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Asynchronous-processing_best_practices_with_AWS_Lambda_SVS406-R1.pdf
# Downladed file: REPEAT_1_Asynchronous-processing_best_practices_with_AWS_Lambda_SVS406-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_A_serverless_journey_AWS_Lambda_under_the_hood_SVS405-R1.pdf
# Downladed file: REPEAT_1_A_serverless_journey_AWS_Lambda_under_the_hood_SVS405-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Networking_best_practices_for_serverless_applications_SVS404-R1.pdf
# Downladed file: REPEAT_1_Networking_best_practices_for_serverless_applications_SVS404-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_for_AWS_Lambda_and_Java_SVS403-R1.pdf
# Downladed file: REPEAT_1_Best_practices_for_AWS_Lambda_and_Java_SVS403-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Building_APIs_from_front_to_back_SVS402-R2.pdf
# Downladed file: REPEAT_2_Building_APIs_from_front_to_back_SVS402-R2.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=13
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Optimizing_your_serverless_applications_SVS401-R1.pdf
# Downladed file: REPEAT_1_Optimizing_your_serverless_applications_SVS401-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Building_APIs_designed_to_push_data_in_real-time_SVS344-R1.pdf
# Downladed file: REPEAT_1_Building_APIs_designed_to_push_data_in_real-time_SVS344-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Building_microservices_with_AWS_Lambda_SVS343-R1.pdf
# Downladed file: REPEAT_1_Building_microservices_with_AWS_Lambda_SVS343-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_machine_learning_applications_with_AWS_Lambda_&_Amazon_SageMaker_SVS342-R1.pdf
# Downladed file: REPEAT_1_Build_machine_learning_applications_with_AWS_Lambda_&_Amazon_SageMaker_SVS342-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_An_in-depth_tour_of_AWS_SAM_SVS341-R1.pdf
# Downladed file: REPEAT_1_An_in-depth_tour_of_AWS_SAM_SVS341-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Serverless_image_processing_workflows_at_scale_with_AWS_Step_Functions_SVS340-R1.pdf
# Downladed file: REPEAT_1_Serverless_image_processing_workflows_at_scale_with_AWS_Step_Functions_SVS340-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_API_patterns_and_architectures_When_and_how_to_use_RESTful_and_GraphQL_APIs_SVS338-R2.pdf
# Downladed file: REPEAT_2_API_patterns_and_architectures_When_and_how_to_use_RESTful_and_GraphQL_APIs_SVS338-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_for_building_multi-region,_active-active_serverless_applications_SVS337-R1.pdf
# Downladed file: REPEAT_1_Best_practices_for_building_multi-region,_active-active_serverless_applications_SVS337-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Serverless_at_scale_Design_patterns_and_optimizations_SVS335-R1.pdf
# Downladed file: REPEAT_1_Serverless_at_scale_Design_patterns_and_optimizations_SVS335-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_&_monitor_a_secure_serverless_app_powered_by_ASP.NET_&_AWS_services_SVS334-R1.pdf
# Downladed file: REPEAT_1_Build_&_monitor_a_secure_serverless_app_powered_by_ASP.NET_&_AWS_services_SVS334-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_serverless_APIs_supported_by_Amazon_Aurora_Serverless_&_the_Data_API_SVS333-R2.pdf
# Downladed file: REPEAT_2_Build_serverless_APIs_supported_by_Amazon_Aurora_Serverless_&_the_Data_API_SVS333-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_AWS_Step_Functions_From_zero_to_hero_SVS332-R2.pdf
# Downladed file: REPEAT_2_AWS_Step_Functions_From_zero_to_hero_SVS332-R2.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=14
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_an_IT_automation_framework_using_AWS_Step_Functions_SVS331-R2.pdf
# Downladed file: REPEAT_2_Build_an_IT_automation_framework_using_AWS_Step_Functions_SVS331-R2.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_secure_serverless_mobile_or_web_applications_SVS330-R2.pdf
# Downladed file: REPEAT_2_Build_secure_serverless_mobile_or_web_applications_SVS330-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_a_conversational_chatbot_&_gain_business_insights_SVS329-R2.pdf
# Downladed file: REPEAT_2_Build_a_conversational_chatbot_&_gain_business_insights_SVS329-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_4_Build_serverless_APIs_with_the_AWS_CDK_SVS327-R4.pdf
# Downladed file: REPEAT_4_Build_serverless_APIs_with_the_AWS_CDK_SVS327-R4.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Pipelining_AWS_Lambda_asynchronous_invocations_SVS326-R1.pdf
# Downladed file: REPEAT_1_Pipelining_AWS_Lambda_asynchronous_invocations_SVS326-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Serverless_big_data_processing_SVS325-R2.pdf
# Downladed file: REPEAT_2_Serverless_big_data_processing_SVS325-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Managing_independent_microservices_behind_Amazon_API_Gateway_SVS324-R1.pdf
# Downladed file: REPEAT_1_Managing_independent_microservices_behind_Amazon_API_Gateway_SVS324-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Mastering_AWS_Lambda_streaming_event_sources_SVS323-R1.pdf
# Downladed file: REPEAT_1_Mastering_AWS_Lambda_streaming_event_sources_SVS323-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_AWS_Lambda_layers_deep_dive_SVS321-R2.pdf
# Downladed file: REPEAT_2_AWS_Lambda_layers_deep_dive_SVS321-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_The_serverless_journey_of_shop.LEGO.com_SVS320-R1.pdf
# Downladed file: REPEAT_1_The_serverless_journey_of_shop.LEGO.com_SVS320-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Serverless_stream_processing_pipeline_best_practices_SVS317-R1.pdf
# Downladed file: REPEAT_1_Serverless_stream_processing_pipeline_best_practices_SVS317-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Serverless_inference_with_AWS_Lambda_SVS315-R1.pdf
# Downladed file: REPEAT_1_Serverless_inference_with_AWS_Lambda_SVS315-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=15
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Securing_enterprise-grade_serverless_apps_SVS310-R1.pdf
# Downladed file: REPEAT_1_Securing_enterprise-grade_serverless_apps_SVS310-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Moving_to_event-driven_architectures_SVS308-R1.pdf
# Downladed file: REPEAT_1_Moving_to_event-driven_architectures_SVS308-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_How_to_secure_your_serverless_applications_SVS305-R1.pdf
# Downladed file: REPEAT_1_How_to_secure_your_serverless_applications_SVS305-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_a_serverless_engine_to_process_large-scale_documents_SVS304-R1.pdf
# Downladed file: REPEAT_1_Build_a_serverless_engine_to_process_large-scale_documents_SVS304-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Monolith_to_serverless_SaaS_A_hands-on_service_decomposition_SVS303-R1.pdf
# Downladed file: REPEAT_1_Monolith_to_serverless_SaaS_A_hands-on_service_decomposition_SVS303-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_a_serverless_online_game_and_real-time_leaderboard_SVS302-R1.pdf
# Downladed file: REPEAT_1_Build_a_serverless_online_game_and_real-time_leaderboard_SVS302-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Delivering_agility_at_McDonald's_with_microservices_transformation_SVS227-S.pdf
# Downladed file: Delivering_agility_at_McDonald's_with_microservices_transformation_SVS227-S.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/From_prototype_to_org-wide_serverless_adoption_Key_considerations_SVS226.pdf
# Downladed file: From_prototype_to_org-wide_serverless_adoption_Key_considerations_SVS226.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_3_AWS_Lambda_function_performance_tuning_SVS224-R3.pdf
# Downladed file: REPEAT_3_AWS_Lambda_function_performance_tuning_SVS224-R3.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Finding_a_home_for_your_data_in_your_serverless_app_SVS223-R1.pdf
# Downladed file: REPEAT_1_Finding_a_home_for_your_data_in_your_serverless_app_SVS223-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Streamline_AWS_Lambda_development_with_Lambda_layers_SVS222-R2.pdf
# Downladed file: REPEAT_2_Streamline_AWS_Lambda_development_with_Lambda_layers_SVS222-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_microservice_APIs_with_Amazon_API_Gateway_SVS220-R1.pdf
# Downladed file: REPEAT_1_Build_microservice_APIs_with_Amazon_API_Gateway_SVS220-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=16
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Serverless_at_scale_SVS219-S.pdf
# Downladed file: Serverless_at_scale_SVS219-S.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_observability_into_a_serverless_application_SVS215-R1.pdf
# Downladed file: REPEAT_1_Build_observability_into_a_serverless_application_SVS215-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Amazon_S3_to_Lambda_A_flexible_pattern_at_the_core_of_serverless_applications_SVS214-R1.pdf
# Downladed file: REPEAT_1_Amazon_S3_to_Lambda_A_flexible_pattern_at_the_core_of_serverless_applications_SVS214-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Thinking_serverless_From_business_problem_to_serverless_solution_SVS213-R1.pdf
# Downladed file: REPEAT_1_Thinking_serverless_From_business_problem_to_serverless_solution_SVS213-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Automatically_scale_a_serverless_app_with_Amazon_Textract_&_MongoDB_SVS210-S.pdf
# Downladed file: Automatically_scale_a_serverless_app_with_Amazon_Textract_&_MongoDB_SVS210-S.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Powering_digital_billboards_with_serverless_SVS209-S.pdf
# Downladed file: Powering_digital_billboards_with_serverless_SVS209-S.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_a_serverless_ride-sharing_web_application_SVS203-R1.pdf
# Downladed file: REPEAT_1_Build_a_serverless_ride-sharing_web_application_SVS203-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_a_serverless_web_app_for_a_theme_park_SVS201-R2.pdf
# Downladed file: REPEAT_2_Build_a_serverless_web_app_for_a_theme_park_SVS201-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Fine-grained_access_control_for_serverless_apps_SEC409-R2.pdf
# Downladed file: REPEAT_2_Fine-grained_access_control_for_serverless_apps_SEC409-R2.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Security_benefits_of_the_Nitro_architecture_SEC408-R1.pdf
# Downladed file: REPEAT_1_Security_benefits_of_the_Nitro_architecture_SEC408-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Deep_dive_on_AWS_CloudHSM_SEC406-R1.pdf
# Downladed file: REPEAT_1_Deep_dive_on_AWS_CloudHSM_SEC406-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Access_management_in_4D_SEC405-R1.pdf
# Downladed file: REPEAT_1_Access_management_in_4D_SEC405-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=17
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Building_secure_APIs_in_the_cloud_SEC404-R1.pdf
# Downladed file: REPEAT_1_Building_secure_APIs_in_the_cloud_SEC404-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_AWS_Identity_Using_Amazon_Cognito_for_serverless_consumer_apps_SEC403-R1.pdf
# ...
# Downladed file: REPEAT_1_Zero_to_hero_Quick_starts_with_Amazon_Redshift_ANT237-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1}_Retail_data_products_on_AWS_Data_Exchange_ANT236-R1.pdf
# Downladed file: REPEAT_1}_Retail_data_products_on_AWS_Data_Exchange_ANT236-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Healthcare_data_products_on_AWS_Data_Exchange_ANT235.pdf
# Downladed file: Healthcare_data_products_on_AWS_Data_Exchange_ANT235.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=112
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Easily_find_&_subscribe_to_third-party_data_in_the_cloud_on_AWS_Data_Exchange_ANT233.pdf
# Downladed file: Easily_find_&_subscribe_to_third-party_data_in_the_cloud_on_AWS_Data_Exchange_ANT233.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_to_become_a_data_provider_with_AWS_Data_Exchange_ANT232.pdf
# Downladed file: How_to_become_a_data_provider_with_AWS_Data_Exchange_ANT232.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/NEW_LAUNCH_Amazon_Redshift_reimagined_RA3_and_AQUA_ANT230.pdf
# Downladed file: NEW_LAUNCH_Amazon_Redshift_reimagined_RA3_and_AQUA_ANT230.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/NEW_LAUNCH_Secure,_scalable,_and_cost-effective_log_analytics_ANT229.pdf
# Downladed file: NEW_LAUNCH_Secure,_scalable,_and_cost-effective_log_analytics_ANT229.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_Petco_transformed_its_legacy_business_for_the_next_generation_ANT228-S.pdf
# Downladed file: How_Petco_transformed_its_legacy_business_for_the_next_generation_ANT228-S.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Preparing_data_for_reporting,_ML,_and_AI_on_AWS_ANT227-S.pdf
# Downladed file: Preparing_data_for_reporting,_ML,_and_AI_on_AWS_ANT227-S.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Lower_costs_on_Amazon_EMR_AWS_Auto_Scaling_and_Spot_pricing_ANT226.pdf
# Downladed file: Lower_costs_on_Amazon_EMR_AWS_Auto_Scaling_and_Spot_pricing_ANT226.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Access_control_for_Amazon_Athena_with_AWS_Lake_Formation_ANT225.pdf
# Downladed file: Access_control_for_Amazon_Athena_with_AWS_Lake_Formation_ANT225.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Using_containers_with_Amazon_EMR_and_Apache_Spark_ANT224-R1.pdf
# Downladed file: REPEAT_1_Using_containers_with_Amazon_EMR_and_Apache_Spark_ANT224-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Spark_access_control_on_Amazon_EMR_with_AWS_Lake_Formation_ANT223-R1.pdf
# Downladed file: REPEAT_1_Spark_access_control_on_Amazon_EMR_with_AWS_Lake_Formation_ANT223-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Analytics_with_Amazon_Athena_ANT222-R1.pdf
# Downladed file: REPEAT_1_Analytics_with_Amazon_Athena_ANT222-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Data_lakes_and_data_integration_with_AWS_Lake_Formation_ANT218-R1.pdf
# Downladed file: REPEAT_1_Data_lakes_and_data_integration_with_AWS_Lake_Formation_ANT218-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=113
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Embedding_analytics_into_applications_with_Amazon_QuickSight_ANT217.pdf
# Downladed file: Embedding_analytics_into_applications_with_Amazon_QuickSight_ANT217.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_ML_analytics_with_Amazon_QuickSight_ANT216-R1.pdf
# Downladed file: REPEAT_1_ML_analytics_with_Amazon_QuickSight_ANT216-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Securing_your_Amazon_Elasticsearch_Service_domain_ANT215-R1.pdf
# Downladed file: REPEAT_1_Securing_your_Amazon_Elasticsearch_Service_domain_ANT215-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_VPC_flow_logs_and_Amazon_Elasticsearch_Service_ANT214-R1.pdf
# Downladed file: REPEAT_1_VPC_flow_logs_and_Amazon_Elasticsearch_Service_ANT214-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_State-of-the-art_cloud_data_warehousing,_featuring_Asurion_ANT213-R1.pdf
# Downladed file: REPEAT_1_State-of-the-art_cloud_data_warehousing,_featuring_Asurion_ANT213-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_State-of-the-art_cloud_data_warehousing,_featuring_Comcast_ANT213-R.pdf
# Downladed file: REPEAT_State-of-the-art_cloud_data_warehousing,_featuring_Comcast_ANT213-R.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Delivering_data_to_your_Amazon_Elasticsearch_Service_domain_ANT212-R1.pdf
# Downladed file: REPEAT_1_Delivering_data_to_your_Amazon_Elasticsearch_Service_domain_ANT212-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Developing_with_the_Amazon_QuickSight_SDK_ANT211-R1.pdf
# Downladed file: REPEAT_1_Developing_with_the_Amazon_QuickSight_SDK_ANT211-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Best_practices_Amazon_Elasticsearch_Service_ANT210-R1.pdf
# Downladed file: REPEAT_1_Best_practices_Amazon_Elasticsearch_Service_ANT210-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Find_matches_using_machine-learning_transforms_in_AWS_Glue_ANT209-R2.pdf
# Downladed file: REPEAT_2_Find_matches_using_machine-learning_transforms_in_AWS_Glue_ANT209-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_4_Serverless_ETL_with_Apache_Spark_and_Python_in_AWS_Glue_ANT208-R4.pdf
# Downladed file: REPEAT_4_Serverless_ETL_with_Apache_Spark_and_Python_in_AWS_Glue_ANT208-R4.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Simplifying_and_modernizing_home_search_at_Compass_with_Amazon_ES_ANT207-R1.pdf
# Downladed file: REPEAT_1_Simplifying_and_modernizing_home_search_at_Compass_with_Amazon_ES_ANT207-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=114
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_What's_new_with_Amazon_Athena_ANT205-R1.pdf
# Downladed file: REPEAT_1_What's_new_with_Amazon_Athena_ANT205-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_How_Amazon_leverages_AWS_to_deliver_analytics_at_enterprise_scale_ANT204-R1.pdf
# Downladed file: REPEAT_1_How_Amazon_leverages_AWS_to_deliver_analytics_at_enterprise_scale_ANT204-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Sophos_Build_security_solutions_using_Amazon_Elasticsearch_Service_ANT203.pdf
# Downladed file: Sophos_Build_security_solutions_using_Amazon_Elasticsearch_Service_ANT203.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Turbocharge_your_Spark_performance_with_Amazon_EMR_ANT202-R1.pdf
# Downladed file: REPEAT_1_Turbocharge_your_Spark_performance_with_Amazon_EMR_ANT202-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Building_workflows_on_AWS_Lake_Formation_&_AWS_Glue_ANT201-R1.pdf
# Downladed file: REPEAT_1_Building_workflows_on_AWS_Lake_Formation_&_AWS_Glue_ANT201-R1.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Amazon.com_automates_machine_learning_life_cycle_on_AWS_AMZ306.pdf
# Downladed file: Amazon.com_automates_machine_learning_life_cycle_on_AWS_AMZ306.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Building_a_virtual_fob_with_Amazon_Key_for_Business_and_AWS_IoT_AMZ305.pdf
# Downladed file: Building_a_virtual_fob_with_Amazon_Key_for_Business_and_AWS_IoT_AMZ305.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Prime_Video_Processing_analytics_at_petabyte_scale_AMZ304.pdf
# Downladed file: Prime_Video_Processing_analytics_at_petabyte_scale_AMZ304.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Modernizing_Amazon_warehouse_device_connections_with_AWS_IoT_AMZ303.pdf
# Downladed file: Modernizing_Amazon_warehouse_device_connections_with_AWS_IoT_AMZ303.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Amazon_Wallet_Increasing_performance_with_DynamoDB_AMZ302.pdf
# Downladed file: Amazon_Wallet_Increasing_performance_with_DynamoDB_AMZ302.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Amazon.com_Enterprise_database_migration_at_scale_AMZ301.pdf
# Downladed file: Amazon.com_Enterprise_database_migration_at_scale_AMZ301.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_an_Alexa_Gadget_ALX403-R1.pdf
# Downladed file: REPEAT_1_Build_an_Alexa_Gadget_ALX403-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=115
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Building_a_multimodal_Alexa_skill_with_Alexa_Presentation_Language_ALX402-R2.pdf
# Downladed file: REPEAT_2_Building_a_multimodal_Alexa_skill_with_Alexa_Presentation_Language_ALX402-R2.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Learn_how_to_handle_data_in_your_Alexa_skills_ALX401-R2.pdf
# Downladed file: REPEAT_2_Learn_how_to_handle_data_in_your_Alexa_skills_ALX401-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/How_to_build_a_multimodal_Alexa_skill_ALX319.pdf
# Downladed file: How_to_build_a_multimodal_Alexa_skill_ALX319.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/DevOps_your_Alexa_skill_Why_testing_and_automation_matter_ALX318.pdf
# Downladed file: DevOps_your_Alexa_skill_Why_testing_and_automation_matter_ALX318.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_3_Learn_to_build_an_Alexa_skill_in_an_hour_with_Cake_Walk_ALX317-R3.pdf
# Downladed file: REPEAT_3_Learn_to_build_an_Alexa_skill_in_an_hour_with_Cake_Walk_ALX317-R3.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Alexa_Conversations_ALX316-R2.pdf
# Downladed file: REPEAT_2_Alexa_Conversations_ALX316-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Improving_customer_retention_for_your_Alexa_skill_ALX315.pdf
# Downladed file: Improving_customer_retention_for_your_Alexa_skill_ALX315.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_your_first_Alexa_skill_from_the_ASK_CLI_ALX314-R2.pdf
# Downladed file: REPEAT_2_Build_your_first_Alexa_skill_from_the_ASK_CLI_ALX314-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Developer_tools_for_Alexa_ALX313.pdf
# Downladed file: Developer_tools_for_Alexa_ALX313.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Design_an_Alexa_skill_with_in-skill_purchasing_ALX312.pdf
# Downladed file: Design_an_Alexa_skill_with_in-skill_purchasing_ALX312.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_How_to_build_Alexa_skills_with_AWS_database_&_storage_services_ALX311-R2.pdf
# Downladed file: REPEAT_2_How_to_build_Alexa_skills_with_AWS_database_&_storage_services_ALX311-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Implementing_a_multi-capability_skill_for_an_AVS-enabled_device_ALX310-R1.pdf
# Downladed file: REPEAT_1_Implementing_a_multi-capability_skill_for_an_AVS-enabled_device_ALX310-R1.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=116
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Building_robots_that_respond_to_voice_ALX306-R1.pdf
# Downladed file: REPEAT_1_Building_robots_that_respond_to_voice_ALX306-R1.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_3_Build_and_monetize_an_Alexa_skill_using_in-skill_purchasing_ALX304-R3.pdf
# Downladed file: REPEAT_3_Build_and_monetize_an_Alexa_skill_using_in-skill_purchasing_ALX304-R3.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Learn_situational_design_with_Cake_Walk_ALX303-R2.pdf
# Downladed file: REPEAT_2_Learn_situational_design_with_Cake_Walk_ALX303-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_Build_an_engaging_Alexa_skill_with_Cake_Walk_ALX302-R2.pdf
# Downladed file: REPEAT_2_Build_an_engaging_Alexa_skill_with_Cake_Walk_ALX302-R2.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Build_your_own_Raspberry_Pi_Alexa_device,_now_with_visuals_ALX301-R1.pdf
# Downladed file: REPEAT_1_Build_your_own_Raspberry_Pi_Alexa_device,_now_with_visuals_ALX301-R1.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Creating_products_with_Alexa_Built-in_using_low-cost_microcontrollers_ALX204-R1.pdf
# Downladed file: REPEAT_1_Creating_products_with_Alexa_Built-in_using_low-cost_microcontrollers_ALX204-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_Go_from_0_to_60_with_Alexa_Connect_Kit_ALX203-R1.pdf
# Downladed file: REPEAT_1_Go_from_0_to_60_with_Alexa_Connect_Kit_ALX203-R1.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_2_How_developers_can_build_natural,_extensible_voice_conversations_ALX201-R2.pdf
# Downladed file: REPEAT_2_How_developers_can_build_natural,_extensible_voice_conversations_ALX201-R2.pdf
# Waiting 3 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Testing_techniques_for_measuring_personalization_ADM402.pdf
# Downladed file: Testing_techniques_for_measuring_personalization_ADM402.pdf
# Waiting 5 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Best_practices_for_identity_resolution_with_Amazon_Neptune_ADM301.pdf
# Downladed file: Best_practices_for_identity_resolution_with_Amazon_Neptune_ADM301.pdf
# Waiting 2 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Reimagining_advertising_analytics_&_identity_resolution_at_scale_ADM203.pdf
# Downladed file: Reimagining_advertising_analytics_&_identity_resolution_at_scale_ADM203.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Analyzing_Amazon_DSP_data_in_an_AWS_data_lake_ADM401.pdf
# Downladed file: Analyzing_Amazon_DSP_data_in_an_AWS_data_lake_ADM401.pdf
# Attempting to access the web page: https://aws.amazon.com/events/events-content/?awsf.filter-series=event-series%23reinvent&awsm.page-cards=117
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/Implementing_Amazon_Personalize_across_marketing_channels_ADM303.pdf
# Downladed file: Implementing_Amazon_Personalize_across_marketing_channels_ADM303.pdf
# Waiting 4 seconds to retrieve https://d1.awsstatic.com/events/reinvent/2019/REPEAT_1_End-to-end_machine_learning_using_Spark_and_Amazon_SageMaker_ADM302-R1.pdf
# Downladed file: REPEAT_1_End-to-end_machine_learning_using_Spark_and_Amazon_SageMaker_ADM302-R1.pdf
# Finished finding all available documents on the web pages!
# Total presentation documents downloaded: 1393

# %%
if (notifyStatus): email_notify("Phase 1 Perform the Scraping and Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 2:50:29.939369
