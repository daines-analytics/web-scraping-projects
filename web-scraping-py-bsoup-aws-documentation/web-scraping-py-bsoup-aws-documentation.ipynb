# %% [markdown]
# # Web Scraping of AWS Documentation Using Python and BeautifulSoup
# ### David Lowe
# ### April 28, 2019
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific information from a website. Using the extracted information, the script further completes other tasks (downloading files in this case). The web scraping python code leverages the BeautifulSoup module.
#
# INTRODUCTION: On occasions, there is a need to download a batch of documents off web pages without clicking on the download links one at a time. This web scraping script will automatically traverse through the necessary web pages and collect all links with the PDF document format. The script will also download the PDF documents as part of the scraping process.
#
# For this script to work, it requires the use of Selenium browser automation software and one of its WebDrivers (Firefox in this case).
#
# Starting URLs: https://docs.aws.amazon.com/

# %% [markdown]
# ## Loading Libraries and Packages

# %%
import os
import sys
import shutil
import smtplib
from email.message import EmailMessage
from datetime import datetime
import urllib.request
from urllib.error import HTTPError
from urllib.error import URLError
from bs4 import BeautifulSoup
from random import randint
from time import sleep
from selenium import webdriver

startTimeScript = datetime.now()

# %% [markdown]
# ## Setting up the necessary parameters

# %%
# Specifying the URL of desired web page to be scrapped
starting_url = "https://docs.aws.amazon.com/"
website_url = "https://docs.aws.amazon.com"

# %%
from selenium.webdriver.firefox.options import Options

firefox_options = Options()
firefox_options.headless = True
browser = webdriver.Firefox(options=firefox_options)
browser.get(starting_url)
sleep(10)
innerHTML = browser.execute_script("return document.body.innerHTML")
sleep(10)
web_page = BeautifulSoup(innerHTML, 'lxml')
browser.quit()
# print(web_page.prettify())

# %% [markdown]
# ## Performing the Scraping and Processing

# %%
# Gather all links to the document
service_collection = web_page.find_all('awsdocs-service-link')
print('Number of potential service documentation groups found:', len(service_collection))
# Out:
# Number of potential service documentation groups found: 200

# %%
i = 0
for svc in service_collection:
    doc_url = svc['href']
    start_string = "/"
    end_string = "?id=docs_gateway"
    if doc_url.endswith(end_string) and doc_url.startswith(start_string):
        doc_url = website_url + doc_url
        doc_url = doc_url[:-len(end_string)]
        print('Accessing the doc page: ' + doc_url)
        browser = webdriver.Firefox(options=firefox_options)
        browser.get(doc_url)
        sleep(10)
        innerHTML = browser.execute_script("return document.body.innerHTML")
        sleep(10)
        doc_page = BeautifulSoup(innerHTML, 'lxml')
        browser.quit()
        doc_collection = doc_page.find_all('awsdocs-link')

        for doc in doc_collection:
            if doc['label'] == "PDF":
                # Adding random wait time so we do not hammer the website needlessly
                waitTime = randint(2,5)
                print("Waiting " + str(waitTime) + " seconds to retrieve the next document.")
                sleep(waitTime)
                test_path = website_url + doc['href']
                if test_path.find(".pdf#") > 0:
                    doc_path = test_path.split("#")[0]
                else:
                    doc_path = test_path
                dest_file = os.path.basename(doc_path)
                print('Downlading document: ' + doc_path + " as " + dest_file)
                # The following two lines of code will download the PDF documents
#                 with urllib.request.urlopen(doc_path) as in_resp, open(dest_file, 'wb') as out_file:
#                     shutil.copyfileobj(in_resp, out_file)
                i = i + 1
# Out:
# Accessing the doc page: https://docs.aws.amazon.com/ec2/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/ec2-ug.pdf as ec2-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSEC2/latest/WindowsGuide/ec2-wg.pdf as ec2-wg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSEC2/latest/APIReference/ec2-api.pdf as ec2-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/ec2/userguide/as-dg.pdf as as-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/ec2/APIReference/as-api.pdf as as-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vm-import/latest/userguide/vm-import-ug.pdf as vm-import-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/batch/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/batch/latest/userguide/batch_user.pdf as batch_user.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/batch/latest/APIReference/batch-api.pdf as batch-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/ecr/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonECR/latest/userguide/ecr-ug.pdf as ecr-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonECR/latest/APIReference/ecr-api.pdf as ecr-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/ecs/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonECS/latest/developerguide/ecs-dg.pdf as ecs-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonECS/latest/userguide/ecs-ug.pdf as ecs-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonECS/latest/APIReference/ecs-api.pdf as ecs-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/eks/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/eks/latest/userguide/eks-ug.pdf as eks-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/eks/latest/APIReference/eks-api.pdf as eks-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/elastic-beanstalk/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticbeanstalk/latest/dg/awseb-dg.pdf as awseb-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticbeanstalk/latest/api/awseb-api.pdf as awseb-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticbeanstalk/latest/dg/awseb-dg.pdf as awseb-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/lambda/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lambda/latest/dg/lambda-dg.pdf as lambda-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/lightsail/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lightsail/2016-11-28/api-reference/amazon-lightsail-api-reference.pdf as amazon-lightsail-api-reference.pdf
# Accessing the doc page: https://docs.aws.amazon.com/serverless-application-model/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/serverless-application-model/latest/developerguide/serverless-application-model.pdf as serverless-application-model.pdf
# Accessing the doc page: https://docs.aws.amazon.com/serverlessrepo/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/serverlessrepo/latest/devguide/serverlessrepo-dg.pdf as serverlessrepo-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/s3/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonS3/latest/gsg/s3-gsg.pdf as s3-gsg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonS3/latest/dev/s3-dg.pdf as s3-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonS3/latest/API/s3-api.pdf as s3-api.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonS3/latest/user-guide/s3-user-guide.pdf as s3-user-guide.pdf
# Accessing the doc page: https://docs.aws.amazon.com/aws-backup/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/aws-backup/latest/devguide/AWSBackup-dg.pdf as AWSBackup-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/AmazonEBS.html
# Accessing the doc page: https://docs.aws.amazon.com/efs/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/efs/latest/ug/efs-ug.pdf as efs-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/fsx/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/fsx/latest/WindowsGuide/WindowsGuide.pdf as WindowsGuide.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/fsx/latest/LustreGuide/LustreGuide.pdf as LustreGuide.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/fsx/latest/APIReference/fsx-api.pdf as fsx-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/glacier/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/amazonglacier/latest/dev/glacier-dg.pdf as glacier-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/snowball/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/snowball/latest/ug/AWSSnowball-ug.pdf as AWSSnowball-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/snowball/latest/developer-guide/AWSSnowball-dg.pdf as AWSSnowball-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/snowball/latest/api-reference/AWSSnowball-api.pdf as AWSSnowball-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/storagegateway/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/storagegateway/latest/userguide/storagegateway-ug.pdf as storagegateway-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/storagegateway/latest/APIReference/storagegateway-api.pdf as storagegateway-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/rds/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/rds-ug.pdf as rds-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonRDS/latest/AuroraUserGuide/aurora-ug.pdf as aurora-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonRDS/latest/APIReference/rds-api.pdf as rds-api.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/performance-insights/latest/APIReference/performance-insights-api.pdf as performance-insights-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/documentdb/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/documentdb/latest/developerguide/developerguide.pdf as developerguide.pdf
# Accessing the doc page: https://docs.aws.amazon.com/dynamodb/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/dynamodb-dg.pdf as dynamodb-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/amazondynamodb/latest/APIReference/dynamodb-api.pdf as dynamodb-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/elasticache/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonElastiCache/latest/red-ug/redis-ug.pdf as redis-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonElastiCache/latest/mem-ug/memcached-ug.pdf as memcached-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonElastiCache/latest/APIReference/elasticache-api.pdf as elasticache-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/neptune/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/neptune/latest/userguide/neptune-ug.pdf as neptune-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/rds/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/rds-ug.pdf as rds-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonRDS/latest/AuroraUserGuide/aurora-ug.pdf as aurora-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonRDS/latest/APIReference/rds-api.pdf as rds-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/performance-insights/latest/APIReference/performance-insights-api.pdf as performance-insights-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/redshift/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/redshift/latest/gsg/redshift-gsg.pdf as redshift-gsg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/redshift/latest/dg/redshift-dg.pdf as redshift-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/redshift/latest/mgmt/redshift-mgmt.pdf as redshift-mgmt.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/redshift/latest/APIReference/redshift-api.pdf as redshift-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloud9/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloud9/latest/user-guide/aws-cloud9-ug.pdf as aws-cloud9-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloud9/latest/APIReference/cloud9-api.pdf as cloud9-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/codebuild/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codebuild/latest/userguide/codebuild-user.pdf as codebuild-user.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codebuild/latest/APIReference/codebuild-api.pdf as codebuild-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/codecommit/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codecommit/latest/userguide/codecommit-user.pdf as codecommit-user.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codecommit/latest/APIReference/codecommit-api.pdf as codecommit-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/codedeploy/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codedeploy/latest/userguide/codedeploy-user.pdf as codedeploy-user.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codedeploy/latest/APIReference/codedeploy-api.pdf as codedeploy-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/codepipeline/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codepipeline/latest/userguide/codepipeline-user.pdf as codepipeline-user.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codepipeline/latest/APIReference/codepipeline-api.pdf as codepipeline-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/codestar/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codestar/latest/userguide/codestar-ug.pdf as codestar-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/codestar/latest/APIReference/AWSCodeStar-api.pdf as AWSCodeStar-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/xray/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/xray/latest/devguide/xray-guide.pdf as xray-guide.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/xray/latest/api/xray-api.pdf as xray-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iam/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/IAM/latest/UserGuide/iam-ug.pdf as iam-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/IAM/latest/APIReference/iam-api.pdf as iam-api.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/STS/latest/APIReference/sts-api.pdf as sts-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/artifact/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/artifact/latest/ug/artifact-ug.pdf as artifact-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cognito/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cognito/latest/developerguide/cognito-dg.pdf as cognito-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cognitoidentity/latest/APIReference/cognito-identity-api.pdf as cognito-identity-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cognitosync/latest/APIReference/cognito-sync-api.pdf as cognito-sync-api.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cognito-user-identity-pools/latest/APIReference/cognito-user-identity-pools-apiref.pdf as cognito-user-identity-pools-apiref.pdf
# Accessing the doc page: https://docs.aws.amazon.com/directory-service/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/directoryservice/latest/APIReference/cds-api.pdf as cds-api.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/directoryservice/latest/admin-guide/directoryservice-admin-guide.pdf as directoryservice-admin-guide.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/clouddirectory/latest/developerguide/clouddirectory-dev-guide.pdf as clouddirectory-dev-guide.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/directoryservice/latest/devguide/directoryservice-api.pdf as directoryservice-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/firewall-manager/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/waf/latest/developerguide/waf-dg.pdf as waf-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/fms/2018-01-01/APIReference/fms-api.pdf as fms-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/clouddirectory/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/clouddirectory/latest/developerguide/clouddirectory-dev-guide.pdf as clouddirectory-dev-guide.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/clouddirectory/latest/APIReference/cds-api.pdf as cds-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/guardduty/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/guardduty/latest/ug/guardduty-ug.pdf as guardduty-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/guardduty/latest/ug/guardduty-ug.pdf as guardduty-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/inspector/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/inspector/latest/userguide/inspector-ug.pdf as inspector-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/inspector/latest/APIReference/inspector.pdf as inspector.pdf
# Accessing the doc page: https://docs.aws.amazon.com/macie/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/macie/latest/userguide/macie-ug.pdf as macie-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/macie/1.0/APIReference/macie-api.pdf as macie-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/ram/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/ram/latest/userguide/ram-ug.pdf as ram-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/ram/latest/APIReference/ram-api.pdf as ram-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/secretsmanager/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/secretsmanager/latest/userguide/secretsmanager-userguide.pdf as secretsmanager-userguide.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/secretsmanager/latest/apireference/secretsmanager-apireference.pdf as secretsmanager-apireference.pdf
# Accessing the doc page: https://docs.aws.amazon.com/securityhub/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/securityhub/latest/userguide/securityhub.pdf as securityhub.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/securityhub/1.0/APIReference/securityhub-api.pdf as securityhub-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/shield/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/waf/latest/developerguide/waf-dg.pdf as waf-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/waf/latest/DDOSAPIReference/AWS-Shield.pdf as AWS-Shield.pdf
# Accessing the doc page: https://docs.aws.amazon.com/singlesignon/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/singlesignon/latest/userguide/sso-ug.pdf as sso-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/waf/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/waf/latest/developerguide/waf-dg.pdf as waf-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/waf/latest/APIReference/waf-apiref.pdf as waf-apiref.pdf
# Accessing the doc page: https://docs.aws.amazon.com/crypto/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/crypto/latest/userguide/crypto-ug.pdf as crypto-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/crypto/latest/userguide/crypto-ug.pdf as crypto-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/crypto/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/crypto/latest/userguide/crypto-ug.pdf as crypto-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/crypto/latest/userguide/crypto-ug.pdf as crypto-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloudhsm/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloudhsm/latest/userguide/cloudhsm-user-guide.pdf as cloudhsm-user-guide.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloudhsm/latest/APIReference/cloudhsm-api.pdf as cloudhsm-api.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloudhsm/classic/userguide/cloudhsm-classic-userguide.pdf as cloudhsm-classic-userguide.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloudhsm/classic/APIReference/cloudhsm-api.pdf as cloudhsm-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/kms/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/kms/latest/developerguide/kms-dg.pdf as kms-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/kms/latest/APIReference/kms-api-reference.pdf as kms-api-reference.pdf
# Accessing the doc page: https://docs.aws.amazon.com/aws-crypto-tools/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/encryption-sdk/latest/developer-guide/encryption-sdk-developer-guide.pdf as encryption-sdk-developer-guide.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dynamodb-encryption-client/latest/devguide/dynamodb-encryption-client.pdf as dynamodb-encryption-client.pdf
# Accessing the doc page: https://docs.aws.amazon.com/acm/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm/latest/userguide/acm-ug.pdf as acm-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm/latest/APIReference/acm-apiref.pdf as acm-apiref.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm-pca/latest/userguide/pca-ug.pdf as pca-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm-pca/latest/APIReference/pca-api.pdf as pca-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/acm/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm/latest/userguide/acm-ug.pdf as acm-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm/latest/APIReference/acm-apiref.pdf as acm-apiref.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm-pca/latest/userguide/pca-ug.pdf as pca-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/acm-pca/latest/APIReference/pca-api.pdf as pca-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/mxnet/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/mxnet/latest/dg/mxnet-dg.pdf as mxnet-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/comprehend/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/comprehend/latest/dg/comprehend-dg.pdf as comprehend-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/comprehend/latest/dg/comprehend-dg.pdf as comprehend-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/dlami/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dlami/latest/devguide/dlami-dg.pdf as dlami-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/deeplens/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/deeplens/latest/dg/deeplens-dg.pdf as deeplens-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/deepracer/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/deepracer/latest/developerguide/awsracerdg.pdf as awsracerdg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/forecast/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/forecast/latest/dg/forecast.dg.pdf as forecast.dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/lex/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lex/latest/dg/lex-dg.pdf as lex-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/machine-learning/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/machine-learning/latest/dg/machinelearning-dg.pdf as machinelearning-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/machine-learning/latest/APIReference/amazonml-api.pdf as amazonml-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/personalize/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/personalize/latest/dg/personalize-dg.pdf as personalize-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/polly/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/polly/latest/dg/polly-dg.pdf as polly-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/rekognition/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/rekognition/latest/dg/rekognition-dg.pdf as rekognition-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sagemaker/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-dg.pdf as sagemaker-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/textract/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/textract/latest/dg/textract-dg.pdf as textract-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/transcribe/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/transcribe/latest/dg/transcribe-dg.pdf as transcribe-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/translate/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/translate/latest/dg/translate-dg.pdf as translate-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/autoscaling/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/plans/userguide/as-plans-ug.pdf as as-plans-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/plans/APIReference/as-plans-api.pdf as as-plans-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/application/userguide/app-as-ug.pdf as app-as-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/application/APIReference/app-as-api.pdf as app-as-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/ec2/userguide/as-dg.pdf as as-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/autoscaling/ec2/APIReference/as-api.pdf as as-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloudformation/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSCloudFormation/latest/UserGuide/cfn-ug.pdf as cfn-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSCloudFormation/latest/APIReference/cfn-api.pdf as cfn-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloudtrail/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awscloudtrail/latest/userguide/awscloudtrail-ug.pdf as awscloudtrail-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awscloudtrail/latest/APIReference/awscloudtrail-api.pdf as awscloudtrail-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloudwatch/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatch/latest/monitoring/acw-ug.pdf as acw-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatch/latest/APIReference/acw-api.pdf as acw-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatch/latest/cli/acw-cli.pdf as acw-cli.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatch/latest/events/cwe-ug.pdf as cwe-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatchEvents/latest/APIReference/cwe-api.pdf as cwe-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatch/latest/logs/cwl-ug.pdf as cwl-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudWatchLogs/latest/APIReference/cwl-api.pdf as cwl-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cli/
# Accessing the doc page: https://docs.aws.amazon.com/config/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/config/latest/developerguide/config-dg.pdf as config-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/config/latest/APIReference/awsconfig-apiref.pdf as awsconfig-apiref.pdf
# Accessing the doc page: https://docs.aws.amazon.com/dlm/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dlm/latest/APIReference/dlm-api.pdf as dlm-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/health/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/health/latest/ug/awshealth-ug.pdf as awshealth-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/health/latest/APIReference/awshealth-api.pdf as awshealth-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/license-manager/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/license-manager/latest/userguide/license-manager.pdf as license-manager.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/license-manager/latest/APIReference/license-manager-api.pdf as license-manager-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/awsconsolehelpdocs/latest/gsg/getting-started.html
# Accessing the doc page: https://docs.aws.amazon.com/opsworks/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/opsworks/latest/userguide/opsworks-ug.pdf as opsworks-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/opsworks/latest/APIReference/opsworks-api.pdf as opsworks-api.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/opsworks-cm/latest/APIReference/opsworks-cm-api.pdf as opsworks-cm-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/organizations/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/organizations/latest/userguide/organizations-userguide.pdf as organizations-userguide.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/organizations/latest/APIReference/organizations-apireference.pdf as organizations-apireference.pdf
# Accessing the doc page: https://docs.aws.amazon.com/servicecatalog/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/servicecatalog/latest/adminguide/service-catalog-ag.pdf as service-catalog-ag.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/servicecatalog/latest/userguide/service-catalog-ug.pdf as service-catalog-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/servicecatalog/latest/dg/service-catalog-dg.pdf as service-catalog-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/systems-manager/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/systems-manager/latest/userguide/systems-manager-ug.pdf as systems-manager-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/systems-manager/latest/APIReference/systems-manager-api.pdf as systems-manager-api.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/ARG/latest/userguide/resgrps-ug.pdf as resgrps-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/ARG/latest/APIReference/resource-groups.pdf as resource-groups.pdf
# Accessing the doc page: https://docs.aws.amazon.com/powershell/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/powershell/latest/userguide/aws-pst-ug.pdf as aws-pst-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/aws-support/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awssupport/latest/user/support-ug.pdf as support-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awssupport/latest/APIReference/support-api.pdf as support-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/wellarchitected/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/wellarchitected/latest/userguide/wellarchitected-ug.pdf as wellarchitected-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/application-discovery/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/application-discovery/latest/userguide/appdiscovery-ug.pdf as appdiscovery-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/application-discovery/latest/APIReference/discovery-api.pdf as discovery-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/dms/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dms/latest/userguide/dms-ug.pdf as dms-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dms/latest/sbs/dms-sbs.pdf as dms-sbs.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dms/latest/APIReference/dms-api.pdf as dms-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/datasync/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/datasync/latest/userguide/sync-dg.pdf as sync-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/migrationhub/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/migrationhub/latest/ug/hub-api.pdf as hub-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/migrationhub/latest/ug/hub-api.pdf as hub-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/SchemaConversionTool/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/SchemaConversionTool/latest/userguide/Schema-Conversion-Tool.pdf as Schema-Conversion-Tool.pdf
# Accessing the doc page: https://docs.aws.amazon.com/server-migration-service/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/server-migration-service/latest/userguide/server-migration-ug.pdf as server-migration-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/server-migration-service/latest/APIReference/server-migration-api.pdf as server-migration-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/snowball/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/snowball/latest/ug/AWSSnowball-ug.pdf as AWSSnowball-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/snowball/latest/developer-guide/AWSSnowball-dg.pdf as AWSSnowball-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/snowball/latest/api-reference/AWSSnowball-api.pdf as AWSSnowball-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/transfer/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/transfer/latest/userguide/sftp.ug.pdf as sftp.ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/amplify/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/amplify/latest/userguide/amplify-console-ug.pdf as amplify-console-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/appsync/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/appsync/latest/devguide/appsync-dg .pdf as appsync-dg .pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/appsync/latest/APIReference/appsync-api.pdf as appsync-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/devicefarm/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/devicefarm/latest/developerguide/devicefarm-dg.pdf as devicefarm-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/devicefarm/latest/APIReference/devicefarm-api.pdf as devicefarm-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-android/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/aws-mobile/latest/developerguide/amhd-dg.pdf as amhd-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-ios/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/aws-mobile/latest/developerguide/amhd-dg.pdf as amhd-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-unity/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/mobile/sdkforunity/developerguide/aws-unity-dg.pdf as aws-unity-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/pinpoint/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint/latest/userguide/pinpoint-ug.pdf as pinpoint-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint/latest/developerguide/pinpoint-dg.pdf as pinpoint-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint/latest/apireference/pinpoint-api.pdf as pinpoint-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint-email/latest/APIReference/pinpoint-email-api.pdf as pinpoint-email-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint-sms-voice/latest/APIReference/sms-voice-api.pdf as sms-voice-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sns/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sns/latest/dg/sns-dg.pdf as sns-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sns/latest/api/sns-api.pdf as sns-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/apigateway/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/apigateway/latest/developerguide/apigateway-dg.pdf as apigateway-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/app-mesh/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/app-mesh/latest/userguide/app-mesh-ug.pdf as app-mesh-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/app-mesh/latest/APIReference/app-mesh-api.pdf as app-mesh-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloud-map/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloud-map/latest/dg/cloud-map-dg.pdf as cloud-map-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloud-map/latest/api/cloud-map-api.pdf as cloud-map-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/cloudfront/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonCloudFront/latest/DeveloperGuide/AmazonCloudFront_DevGuide.pdf as AmazonCloudFront_DevGuide.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/cloudfront/latest/APIReference/cloudfront-api.pdf as cloudfront-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/directconnect/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/directconnect/latest/UserGuide/dc-ug.pdf as dc-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/directconnect/latest/APIReference/dc-api.pdf as dc-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/elasticloadbalancing/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticloadbalancing/latest/userguide/elb-ug.pdf as elb-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticloadbalancing/latest/application/elb-ag.pdf as elb-ag.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticloadbalancing/latest/network/elb-ng.pdf as elb-ng.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticloadbalancing/latest/APIReference/elb-v2-api.pdf as elb-v2-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticloadbalancing/latest/classic/elb-classic.pdf as elb-classic.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elasticloadbalancing/2012-06-01/APIReference/elb-api.pdf as elb-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/global-accelerator/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/global-accelerator/latest/dg/global-accelerator-guide.pdf as global-accelerator-guide.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/global-accelerator/latest/api/global-accelerator-api.pdf as global-accelerator-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/route53/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/Route53/latest/DeveloperGuide/route53-dg.pdf as route53-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/Route53/latest/APIReference/route53-apiref.pdf as route53-apiref.pdf
# Accessing the doc page: https://docs.aws.amazon.com/vpc/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonVPC/latest/UserGuide/vpc-ug.pdf as vpc-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonVPC/latest/PeeringGuide/vpc-pg.pdf as vpc-pg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AmazonVPC/latest/NetworkAdminGuide/vpc-nag.pdf as vpc-nag.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vpc/latest/tgw/vpc-tgw.pdf as vpc-tgw.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSEC2/latest/APIReference/ec2-api.pdf as ec2-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/vpn/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vpn/latest/s2svpn/s2s-vpn-user-guide.pdf as s2s-vpn-user-guide.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vpc/latest/adminguide/vpc-nag.pdf as vpc-nag.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSEC2/latest/APIReference/ec2-api.pdf as ec2-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vpn/latest/clientvpn-user/client-vpn-user-guide.pdf as client-vpn-user-guide.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vpn/latest/clientvpn-admin/client-vpn-admin-guide.pdf as client-vpn-admin-guide.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/AWSEC2/latest/APIReference/ec2-api.pdf as ec2-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/elastic-transcoder/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elastictranscoder/latest/developerguide/elastictranscoder-dg.pdf as elastictranscoder-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/elastictranscoder/latest/developerguide/elastictranscoder-dg.pdf as elastictranscoder-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/mediaconnect/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/mediaconnect/latest/ug/mediaconnect-ug.pdf as mediaconnect-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/mediaconnect/latest/api/mediaconnect-api.pdf as mediaconnect-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/mediaconvert/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/mediaconvert/latest/ug/mediaconvert-guide.pdf as mediaconvert-guide.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/mediaconvert/latest/apireference/mediaconvert-api.pdf as mediaconvert-api.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/speke/latest/documentation/speke.pdf as speke.pdf
# Accessing the doc page: https://docs.aws.amazon.com/medialive/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/medialive/latest/ug/medialive-ug.pdf as medialive-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# ...
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/managed-blockchain/latest/APIReference/managedblockchain-api.pdf as managedblockchain-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/gamelift/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/gamelift/latest/developerguide/gamelift-dg.pdf as gamelift-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/gamelift/latest/apireference/gamelift-api.pdf as gamelift-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/lumberyard/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lumberyard/latest/gettingstartedguide/lumberyard-gsg.pdf as lumberyard-gsg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lumberyard/latest/userguide/lumberyard-ug.pdf as lumberyard-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lumberyard/latest/releasenotes/lumberyard-relnotes.pdf as lumberyard-relnotes.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/lumberyard/latest/legacyreference/lumberyard-legacy.pdf as lumberyard-legacy.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sumerian/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sumerian/latest/userguide/sumerian-guide.pdf as sumerian-guide.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iot/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/developerguide/iot-dg.pdf as iot-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/apireference/iot-api.pdf as iot-api.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/developerguide/iot-dg.pdf as iot-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/freertos/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/freertos/latest/userguide/freertos-ug.pdf as freertos-ug.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/freertos-kernel/latest/ref/freertos-kernel-ref.pdf as freertos-kernel-ref.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/freertos-kernel/latest/dg/freertos-kernel-dg.pdf as freertos-kernel-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iotanalytics/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iotanalytics/latest/userguide/analytics-ug.pdf as analytics-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iotanalytics/latest/APIReference/aws-iot-analytics-api.pdf as aws-iot-analytics-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iot-device-defender/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/developerguide/iot-dg.pdf as iot-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/apireference/iot-api.pdf as iot-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iot-device-management/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/developerguide/iot-dg.pdf as iot-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot/latest/apireference/iot-api.pdf as iot-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iotevents/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iotevents/latest/developerguide/iotevents-dg.pdf as iotevents-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/greengrass/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/greengrass/latest/developerguide/gg-dg.pdf as gg-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/greengrass/latest/apireference/gg-api.pdf as gg-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iot-sitewise/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot-sitewise/latest/userguide/sitewise-guide.pdf as sitewise-guide.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot-sitewise/latest/APIReference/sitewise-api.pdf as sitewise-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/thingsgraph/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/thingsgraph/latest/ug/amazon-things-graph.pdf as amazon-things-graph.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/thingsgraph/latest/APIReference/iot-thingsgraph-api.pdf as iot-thingsgraph-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/iot-1-click/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot-1-click/latest/developerguide/iot-1-click-dg.pdf as iot-1-click-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot-1-click/latest/projects-apireference/1click-papi.pdf as 1click-papi.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/iot-1-click/1.0/devices-apireference/1click-dapi.pdf as 1click-dapi.pdf
# Accessing the doc page: https://docs.aws.amazon.com/connect/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/connect/latest/adminguide/connect-ag.pdf as connect-ag.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/connect/latest/userguide/connect-ug.pdf as connect-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/connect/latest/APIReference/connect-api.pdf as connect-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/pinpoint/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint/latest/userguide/pinpoint-ug.pdf as pinpoint-ug.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint/latest/developerguide/pinpoint-dg.pdf as pinpoint-dg.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint/latest/apireference/pinpoint-api.pdf as pinpoint-api.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint-email/latest/APIReference/pinpoint-email-api.pdf as pinpoint-email-api.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pinpoint-sms-voice/latest/APIReference/sms-voice-api.pdf as sms-voice-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/ses/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/ses/latest/DeveloperGuide/ses-dg.pdf as ses-dg.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/ses/latest/APIReference/ses-api.pdf as ses-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/corretto/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/corretto/latest/corretto-8-ug/corretto-8-ug.pdf as corretto-8-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/corretto/latest/corretto-11-ug/corretto-11-ug.pdf as corretto-11-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/aws-crypto-tools/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/encryption-sdk/latest/developer-guide/encryption-sdk-developer-guide.pdf as encryption-sdk-developer-guide.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/dynamodb-encryption-client/latest/devguide/dynamodb-encryption-client.pdf as dynamodb-encryption-client.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-net/v3/ndg
# Accessing the doc page: https://docs.aws.amazon.com/serverless-application-model/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/serverless-application-model/latest/developerguide/serverless-application-model.pdf as serverless-application-model.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-cpp/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-cpp/v1/developer-guide/aws-sdk-cpp-dg.pdf as aws-sdk-cpp-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-go/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-go/v1/developer-guide/aws-sdk-go-dg.pdf as aws-sdk-go-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-java/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-java/v1/developer-guide/aws-sdk-java-dg.pdf as aws-sdk-java-dg.pdf
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-java/v2/developer-guide/aws-sdk-java-dg.pdf as aws-sdk-java-dg.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-java/v2/migration-guide/aws-sdk-java-mg.pdf as aws-sdk-java-mg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-javascript/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-javascript/v2/developer-guide/js-sdk-dv.pdf as js-sdk-dv.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-net/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-net/v3/developer-guide/aws-sdk-net-v3-dg.pdf as aws-sdk-net-v3-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-php/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-php/v3/developer-guide/aws-sdk-php-v3-developer-guide.pdf as aws-sdk-php-v3-developer-guide.pdf
# Accessing the doc page: https://docs.aws.amazon.com/sdk-for-ruby/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/sdk-for-ruby/v3/developer-guide/aws-sdk-ruby-dg.pdf as aws-sdk-ruby-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/awstoolkiteclipse/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/toolkit-for-eclipse/v1/user-guide/aws-tke-ug.pdf as aws-tke-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/toolkit-for-jetbrains/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/toolkit-for-jetbrains/latest/userguide/aws-tkj-ug.pdf as aws-tkj-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/aws-toolkit-visual-studio/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/toolkit-for-visual-studio/latest/user-guide/aws-tkv-ug.pdf as aws-tkv-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/toolkit-for-vscode/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/toolkit-for-vscode/latest/userguide/aws-tookit-vscode-ug.pdf as aws-tookit-vscode-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/vsts/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/vsts/latest/userguide/vsts-ug.pdf as vsts-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/general/latest/gr/aws-arns-and-namespaces.html
# Accessing the doc page: https://docs.aws.amazon.com/general/latest/gr/glos-chap.html
# Accessing the doc page: https://docs.aws.amazon.com/general/latest/gr/rande.html
# Accessing the doc page: https://docs.aws.amazon.com/general/latest/gr/aws-security-credentials.html
# Accessing the doc page: https://docs.aws.amazon.com/general/latest/gr/aws_service_limits.html
# Accessing the doc page: https://docs.aws.amazon.com/awsconsolehelpdocs/latest/gsg/getting-started.html
# Accessing the doc page: https://docs.aws.amazon.com/ARG/latest/userguide/welcome.html
# Accessing the doc page: https://docs.aws.amazon.com/resourcegroupstagging/latest/APIReference/Welcome.html
# Accessing the doc page: https://docs.aws.amazon.com/awsconsolehelpdocs/latest/gsg/tag-editor.html
# Accessing the doc page: https://docs.aws.amazon.com/alexa-top-sites/
# Accessing the doc page: https://docs.aws.amazon.com/awis/
# Accessing the doc page: https://docs.aws.amazon.com/account-billing/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awsaccountbilling/latest/aboutv2/awsaccountbilling-aboutv2.pdf as awsaccountbilling-aboutv2.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/aws-cost-management/latest/APIReference/awsbilling-api.pdf as awsbilling-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/pricing-calculator/latest/userguide/aws-pc.pdf as aws-pc.pdf
# Accessing the doc page: https://docs.aws.amazon.com/aws-support/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awssupport/latest/user/support-ug.pdf as support-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/awssupport/latest/APIReference/support-api.pdf as support-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/blockchain-templates/
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/blockchain-templates/latest/developerguide/blockchain-templates-dg.pdf as blockchain-templates-dg.pdf
# Accessing the doc page: https://docs.aws.amazon.com/general/latest/gr/Welcome.html
# Accessing the doc page: https://docs.aws.amazon.com/code-samples/latest/catalog/welcome.html
# Accessing the doc page: https://docs.aws.amazon.com/govcloud-us/
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/govcloud-us/latest/ug-west/govcloud-us-west-ug.pdf as govcloud-us-west-ug.pdf
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/govcloud-us/latest/ug-east/govcloud-us-east-ug.pdf as govcloud-us-east-ug.pdf
# Accessing the doc page: https://docs.aws.amazon.com/marketplace/
# Waiting 3 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/marketplace/latest/userguide/aws-marketplace-ug.pdf as aws-marketplace-ug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/marketplace/latest/buyerguide/aws-marketplace-bug.pdf as aws-marketplace-bug.pdf
# Waiting 4 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/marketplacemetering/latest/APIReference/marketplacemetering-api.pdf as marketplacemetering-api.pdf
# Waiting 5 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/marketplaceentitlement/latest/APIReference/marketplaceentitlement-api.pdf as marketplaceentitlement-api.pdf
# Accessing the doc page: https://docs.aws.amazon.com/silk/
# Waiting 2 seconds to retrieve the next document.
# Downlading document: https://docs.aws.amazon.com/silk/latest/developerguide/silk-dg.pdf as silk-dg.pdf

# %%
print('Number of documents processed:', i)
# Out:
# Number of documents processed: 392

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 1:50:33.121529
