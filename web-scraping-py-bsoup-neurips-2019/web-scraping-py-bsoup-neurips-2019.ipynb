# %% [markdown]
# # Web Scraping of NeurIPS Conference 2019 Using Python and BeautifulSoup
# ### David Lowe
# ### January 10, 2020
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific pieces of information from a website. The web scraping Python code leverages the BeautifulSoup module.
#
# INTRODUCTION: The Conference on Neural Information Processing Systems (NeurIPS) covers a wide range of topics in neural information processing systems and research for the biological, technological, mathematical, and theoretical applications. Neural information processing is a field that benefits from a combined view of biological, physical, mathematical, and computational sciences. This web scraping script will automatically traverse through the entire web page and collect all links to the PDF and PPTX documents. The script will also download the documents as part of the scraping process.
#
# Starting URLs: https://papers.nips.cc/book/advances-in-neural-information-processing-systems-32-2019

# %% [markdown]
# ## Section 0. Prepare Environment

# %%
# Colab-Specific Setup - Refresh Linux package repositories and set up additional Linux and Python tools
# !apt-get update
# !apt install chromium-chromedriver
# !pip install -q pymysql selenium

# %%
import numpy as np
import pandas as pd
import os
import shutil
import smtplib
import sys
from email.message import EmailMessage
from datetime import datetime
import requests
from requests.exceptions import HTTPError
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
from random import randint
from time import sleep
# from selenium import webdriver

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose and debug flags to print detailed messages for debugging (setting True will activate!)
verbose = False
debug = False

# Set up the flag to send status emails (setting to True will send the status emails!)
notifyStatus = False

# Set up the mountStorage flag to mount G Drive for storing files (setting True will mount the drive!)
mountStorage = False

# Set up the executeDownload flag to download files (setting True will download!)
executeDownload = True

# %%
# Colab-Specific Setup - Mount Google Drive for storing downloaded files
if (mountStorage):
    from google.colab import drive
    drive.mount('/content/gdrive')

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Web Scraping Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
def access_url(url):
    # Creating an html document from the URL
    uastring = "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:71.0) Gecko/20100101 Firefox/71.0"
    headers={'User-Agent': uastring}
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve the next URL.")
    sleep(waitTime)
    try:
        s = requests.Session()
        resp = s.get(url, headers=headers)
        if (debug): print(resp.text)
    except HTTPError as e:
        print('The server could not serve up the web page!')
        sys.exit("Script processing cannot continue!!!")
    except ConnectionError as e:
        print('The server could not be reached due to connection issues!')
        sys.exit("Script processing cannot continue!!!")

    if (resp.status_code==requests.codes.ok):
        print('Successfully accessed the web page: ' + url)
        bsoup_obj = BeautifulSoup(resp.text, 'lxml')
        return(bsoup_obj)

# %%
def download_to_local(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    if (os.path.isfile(local_file) == False):
        with requests.get(doc_path, stream=True) as r:
            with open(local_file, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print('Downladed file: ' + local_file)
    else:
        print('Skipped existing file: ' + local_file)

# %%
def download_to_gdrive(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
    dest_file = gdrivePrefix + local_file
    with requests.get(doc_path, stream=True) as r:
        with open(dest_file, 'wb') as f:
            shutil.copyfileobj(r.raw, f)
    print('Downladed file: ' + dest_file)

# %%
if (notifyStatus): email_notify("Phase 0 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 1. Perform the Scraping and Processing

# %%
if (notifyStatus): email_notify("Phase 1 Perform the Scraping and Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Specifying the URL of desired web page to be scrapped
starting_url = "https://papers.nips.cc/book/advances-in-neural-information-processing-systems-32-2019"
website_url = "https://papers.nips.cc"

# %%
# Access and test the starting URL
web_page = access_url(starting_url)

# Gather all document links from the starting URL (Two Levels)
collection = web_page.find_all('li')
i = 0

# Delete the first li element as it is not a regular list item we need
collection.pop(0)

for item in collection:
    if (verbose): print(item)
    doc_title = item.a.string
    author_group = item.find_all('a', {'class':'author'})
    author_list = []
    for each_author in author_group:
        author_list.append(each_author.string)
    authors = ''.join(author_list)
    doc_link = website_url + item.a['href']

    doc_page = access_url(doc_link)
    artifact_list = doc_page.find('div', class_="main wrapper clearfix").find_all('a')
    for artifact_item in artifact_list:
        if artifact_item.string == "[PDF]":
            doc_path = website_url + artifact_item['href']
            if (executeDownload):
                if (mountStorage):
                    download_to_gdrive(doc_path)
                else:
                    download_to_local(doc_path)
    i = i + 1

print('Finished finding all available documents on the web pages!')
print('Number of documents processed:', i)
# Out:
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/book/advances-in-neural-information-processing-systems-32-2019
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation.pdf
# Downladed file: 8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks.pdf
# Downladed file: 8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers.pdf
# Downladed file: 8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video.pdf
# Downladed file: 8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning.pdf
# Downladed file: 8300-zero-shot-learning-via-simultaneous-generating-and-learning.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability.pdf
# Downladed file: 8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models.pdf
# Downladed file: 8302-stand-alone-self-attention-in-vision-models.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks.pdf
# Downladed file: 8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos.pdf
# Downladed file: 8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism.pdf
# Downladed file: 8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients.pdf
# Downladed file: 8306-meta-learning-with-implicit-gradients.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features.pdf
# Downladed file: 8307-adversarial-examples-are-not-bugs-they-are-features.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks.pdf
# Downladed file: 8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection.pdf
# Downladed file: 8309-freeanchor-learning-to-match-anchors-for-visual-object-detection.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8310-private-hypothesis-selection
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8310-private-hypothesis-selection.pdf
# Downladed file: 8310-private-hypothesis-selection.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians.pdf
# Downladed file: 8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation.pdf
# Downladed file: 8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data.pdf
# Downladed file: 8313-multi-resolution-weak-supervision-for-sequential-data.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision.pdf
# Downladed file: 8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection.pdf
# Downladed file: 8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle.pdf
# Downladed file: 8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagre
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9705-imitation-projected-programmatic-reinforcement-learning.pdf
# Downladed file: 9705-imitation-projected-programmatic-reinforcement-learning.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9706-learning-data-manipulation-for-augmentation-and-weighting
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9706-learning-data-manipulation-for-augmentation-and-weighting.pdf
# Downladed file: 9706-learning-data-manipulation-for-augmentation-and-weighting.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9707-exploring-algorithmic-fairness-in-robust-graph-covering-problems
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9707-exploring-algorithmic-fairness-in-robust-graph-covering-problems.pdf
# Downladed file: 9707-exploring-algorithmic-fairness-in-robust-graph-covering-problems.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9708-abstraction-based-output-range-analysis-for-neural-networks
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9708-abstraction-based-output-range-analysis-for-neural-networks.pdf
# Downladed file: 9708-abstraction-based-output-range-analysis-for-neural-networks.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9709-space-and-time-efficient-kernel-density-estimation-in-high-dimensions
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9709-space-and-time-efficient-kernel-density-estimation-in-high-dimensions.pdf
# Downladed file: 9709-space-and-time-efficient-kernel-density-estimation-in-high-dimensions.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9710-pidforest-anomaly-detection-via-partial-identification
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9710-pidforest-anomaly-detection-via-partial-identification.pdf
# Downladed file: 9710-pidforest-anomaly-detection-via-partial-identification.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design.pdf
# Downladed file: 9711-generative-models-for-graph-based-protein-design.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision.pdf
# Downladed file: 9712-the-geometry-of-deep-networks-power-diagram-subdivision.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets.pdf
# Downladed file: 9713-approximate-feature-collisions-in-neural-nets.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication.pdf
# Downladed file: 9714-ease-of-teaching-and-language-structure-from-emergent-communication.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach.pdf
# Downladed file: 9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation.pdf
# Downladed file: 9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples.pdf
# Downladed file: 9717-on-relating-explanations-and-adversarial-examples.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns.pdf
# Downladed file: 9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns.pdf
# Waiting 5 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks.pdf
# Downladed file: 9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks.pdf
# Waiting 3 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning.pdf
# Downladed file: 9720-self-attention-with-functional-time-representation-learning.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling.pdf
# Downladed file: 9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling.pdf
# Waiting 4 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data.pdf
# Downladed file: 9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data.pdf
# Waiting 2 seconds to retrieve the next URL.
# Successfully accessed the web page: https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently.pdf
# Downladed file: 9723-mixtape-breaking-the-softmax-bottleneck-efficiently.pdf
# Finished finding all available documents on the web pages!
# Number of documents processed: 1427

# %%
if (notifyStatus): email_notify("Phase 1 Perform the Scraping and Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 2:58:23.972607
