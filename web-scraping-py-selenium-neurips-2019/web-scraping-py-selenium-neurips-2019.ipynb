# %% [markdown]
# # Web Scraping of NeurIPS 2019 Conference Using Python and Selenium
# ### David Lowe
# ### January 17, 2020
#
# SUMMARY: The purpose of this project is to practice web scraping by extracting specific pieces of information from a website. The web scraping Python code leverages the Selenium module.
#
# INTRODUCTION: INTRODUCTION: The Conference on Neural Information Processing Systems (NeurIPS) covers a wide range of topics in neural information processing systems and research for the biological, technological, mathematical, and theoretical applications. Neural information processing is a field that benefits from a combined view of biological, physical, mathematical, and computational sciences. This web scraping script will automatically traverse through the entire web page and collect all links to the PDF and PPTX documents. The script will also download the documents as part of the scraping process.
#
# Starting URLs: https://papers.nips.cc/book/advances-in-neural-information-processing-systems-32-2019

# %% [markdown]
# ## Section 1. Prepare Environment

# %%
import os
import shutil
import smtplib
import sys
from email.message import EmailMessage
from datetime import datetime
from random import randint
from time import sleep
# from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose and debug flags to print detailed messages for debugging (setting True will activate!)
verbose = True
debug = False

# Set up the flag to send status emails (setting to True will send the status emails!)
notifyStatus = False

# Set up the mountStorage flag to mount G Drive for storing files (setting True will mount the drive!)
mountStorage = False

# Set up the executeDownload flag to download files (setting True will download!)
executeDownload = True

# %%
# Colab-Specific Setup - Mount Google Drive for storing downloaded files
if (mountStorage):
    from google.colab import drive
    drive.mount('/content/gdrive')

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Web Scraping Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
def download_to_local(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    if (os.path.isfile(local_file) == False):
        with requests.get(doc_path, stream=True) as r:
            with open(local_file, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print('Downladed file: ' + local_file)
    else:
        print('Skipped existing file: ' + local_file)

# %%
def download_to_gdrive(doc_path):
    # Adding random wait time so we do not hammer the website needlessly
    waitTime = randint(2,5)
    print("Waiting " + str(waitTime) + " seconds to retrieve " + doc_path)
    sleep(waitTime)
    local_file = doc_path.split('/')[-1]
    gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
    dest_file = gdrivePrefix + local_file
    with requests.get(doc_path, stream=True) as r:
        with open(dest_file, 'wb') as f:
            shutil.copyfileobj(r.raw, f)
    print('Downladed file: ' + dest_file)

# %%
if (notifyStatus): email_notify("Phase 1 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 1. Perform the Scraping and Processing

# %%
if (notifyStatus): email_notify("Phase 2 Perform the Scraping and Processing has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Specifying the URL of desired web page to be scrapped
website_url = "https://papers.nips.cc"
starting_url = website_url + "/book/advances-in-neural-information-processing-systems-32-2019"

# %%
# Access and test the starting URL
firefox_options = Options()
firefox_options.headless = False
home_page_browser = webdriver.Firefox(options=firefox_options)
print('Attempting to access the web page: ' + starting_url)
home_page_browser.get(starting_url)

# Gather all document links from the starting URL
main_page_container = home_page_browser.find_element_by_class_name('main-container')
collection = main_page_container.find_elements_by_tag_name('li')
num_presentations = 0
num_documents = 0
# Out:
# Attempting to access the web page: https://papers.nips.cc/book/advances-in-neural-information-processing-systems-32-2019

# %%
doc_page_browser = webdriver.Firefox(options=firefox_options)
for item in collection:
    if (debug): print(item)
    presentation_element = item.find_element_by_tag_name('a')
    doc_title = presentation_element.text
    if (verbose): print("Found title:", doc_title)
    doc_link = presentation_element.get_attribute('href')
    if (verbose): print("Found link:", doc_link)
    author_group = item.find_elements_by_class_name('author')
    author_list = []
    for each_author in author_group:
        author_list.append(each_author.text)
    authors = '|'.join(author_list)
    if (verbose): print("Found authors:", authors)

    doc_page_browser.get(doc_link)
    doc_page_container = doc_page_browser.find_element_by_class_name('main-container')
    doc_abstract = doc_page_container.find_element_by_class_name('abstract')
    if (verbose): print("Found abstract:", doc_abstract)
    artifact_list = doc_page_container.find_elements_by_tag_name('a')
    for artifact_item in artifact_list:
        if (artifact_item.text == "[PDF]"):
            doc_path = artifact_item.get_attribute('href')
            if (verbose): print("Found PDF:", doc_path)
            if (executeDownload):
                if (mountStorage):
                    download_to_gdrive(doc_path)
                else:
                    download_to_local(doc_path)
            num_documents = num_documents + 1
        if (artifact_item.text == "[Supplemental]"):
            doc_path = artifact_item.get_attribute('href')
            if (verbose): print("Found Supplemental:", doc_path)
            if (executeDownload):
                if (mountStorage):
                    download_to_gdrive(doc_path)
                else:
                    download_to_local(doc_path)
            num_documents = num_documents + 1
    num_presentations = num_presentations + 1
doc_page_browser.quit()
# Out:
# Found title: Multimodal Model-Agnostic Meta-Learning via Task-Aware Modulation
# Found link: https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation
# Found authors: Risto Vuorio|Shao-Hua Sun|Hexiang Hu|Joseph J. Lim
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="6949c871-148f-49ef-be92-3e44d5871de8")>
# Found PDF: https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation.pdf
# Downladed file: 8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation.pdf
# Found Supplemental: https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation-supplemental.zip
# Downladed file: 8296-multimodal-model-agnostic-meta-learning-via-task-aware-modulation-supplemental.zip
# Found title: ViLBERT: Pretraining Task-Agnostic Visiolinguistic Representations for Vision-and-Language Tasks
# Found link: https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks
# Found authors: Jiasen Lu|Dhruv Batra|Devi Parikh|Stefan Lee
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="d01d1e37-5f4f-47a5-9357-6c1592881e09")>
# Found PDF: https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks.pdf
# Downladed file: 8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks.pdf
# Found Supplemental: https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks-supplemental.zip
# Downladed file: 8297-vilbert-pretraining-task-agnostic-visiolinguistic-representations-for-vision-and-language-tasks-supplemental.zip
# Found title: Stochastic Shared Embeddings: Data-driven Regularization of Embedding Layers
# Found link: https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers
# Found authors: Liwei Wu|Shuqing Li|Cho-Jui Hsieh|James L. Sharpnack
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="c116619c-dd3c-4cc0-97ee-f947866492b8")>
# Found PDF: https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers.pdf
# Downladed file: 8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers.pdf
# Found Supplemental: https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers-supplemental.zip
# Downladed file: 8298-stochastic-shared-embeddings-data-driven-regularization-of-embedding-layers-supplemental.zip
# Found title: Unsupervised Scale-consistent Depth and Ego-motion Learning from Monocular Video
# Found link: https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video
# Found authors: Jiawang Bian|Zhichao Li|Naiyan Wang|Huangying Zhan|Chunhua Shen|Ming-Ming Cheng|Ian Reid
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="8b51f0eb-bc87-43e3-ad09-90cbcc6cfaf8")>
# Found PDF: https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video.pdf
# Downladed file: 8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video.pdf
# Found Supplemental: https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video-supplemental.zip
# Downladed file: 8299-unsupervised-scale-consistent-depth-and-ego-motion-learning-from-monocular-video-supplemental.zip
# Found title: Zero-shot Learning via Simultaneous Generating and Learning
# Found link: https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning
# Found authors: Hyeonwoo Yu|Beomhee Lee
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="4aab62af-5bde-4424-9ef1-2f05a9f5862c")>
# Found PDF: https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning.pdf
# Downladed file: 8300-zero-shot-learning-via-simultaneous-generating-and-learning.pdf
# Found Supplemental: https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8300-zero-shot-learning-via-simultaneous-generating-and-learning-supplemental.zip
# Downladed file: 8300-zero-shot-learning-via-simultaneous-generating-and-learning-supplemental.zip
# Found title: Ask not what AI can do, but what AI should do: Towards a framework of task delegability
# Found link: https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability
# Found authors: Brian Lubars|Chenhao Tan
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="3b79bae8-661c-40fc-a60e-f5201161b000")>
# Found PDF: https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability.pdf
# Downladed file: 8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability.pdf
# Found Supplemental: https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability-supplemental.zip
# Downladed file: 8301-ask-not-what-ai-can-do-but-what-ai-should-do-towards-a-framework-of-task-delegability-supplemental.zip
# Found title: Stand-Alone Self-Attention in Vision Models
# Found link: https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models
# Found authors: Niki Parmar|Prajit Ramachandran|Ashish Vaswani|Irwan Bello|Anselm Levskaya|Jon Shlens
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="ab876cad-0a6a-4b43-b9f4-8af207f4b9f0")>
# Found PDF: https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models.pdf
# Downladed file: 8302-stand-alone-self-attention-in-vision-models.pdf
# Found Supplemental: https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8302-stand-alone-self-attention-in-vision-models-supplemental.zip
# Downladed file: 8302-stand-alone-self-attention-in-vision-models-supplemental.zip
# Found title: High Fidelity Video Prediction with Large Stochastic Recurrent Neural Networks
# Found link: https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks
# Found authors: Ruben Villegas|Arkanath Pathak|Harini Kannan|Dumitru Erhan|Quoc V. Le|Honglak Lee
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="3e058a4a-cffc-4a17-a688-06b47c6d068f")>
# Found PDF: https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks.pdf
# Downladed file: 8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks.pdf
# Found Supplemental: https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks-supplemental.zip
# Downladed file: 8303-high-fidelity-video-prediction-with-large-stochastic-recurrent-neural-networks-supplemental.zip
# Found title: Unsupervised learning of object structure and dynamics from videos
# Found link: https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos
# Found authors: Matthias Minderer|Chen Sun|Ruben Villegas|Forrester Cole|Kevin P. Murphy|Honglak Lee
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="6c0ae8ba-23ca-4760-9cf8-c912a96f9eb9")>
# Found PDF: https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos.pdf
# Downladed file: 8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos.pdf
# Found Supplemental: https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos-supplemental.zip
# Downladed file: 8304-unsupervised-learning-of-object-structure-and-dynamics-from-videos-supplemental.zip
# Found title: GPipe: Efficient Training of Giant Neural Networks using Pipeline Parallelism
# Found link: https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism
# Found authors: Yanping Huang|Youlong Cheng|Ankur Bapna|Orhan Firat|Dehao Chen|Mia Chen|HyoukJoong Lee|Jiquan Ngiam|Quoc V. Le|Yonghui Wu|zhifeng Chen
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="ed81be1a-e9e3-45d4-b5d7-3360dbcab109")>
# Found PDF: https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism.pdf
# Downladed file: 8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism.pdf
# Found Supplemental: https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism-supplemental.zip
# Downladed file: 8305-gpipe-efficient-training-of-giant-neural-networks-using-pipeline-parallelism-supplemental.zip
# Found title: Meta-Learning with Implicit Gradients
# Found link: https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients
# Found authors: Aravind Rajeswaran|Chelsea Finn|Sham M. Kakade|Sergey Levine
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="8a54bd86-4c93-486e-8dcc-3b0898754c06")>
# Found PDF: https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients.pdf
# Downladed file: 8306-meta-learning-with-implicit-gradients.pdf
# Found Supplemental: https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8306-meta-learning-with-implicit-gradients-supplemental.zip
# Downladed file: 8306-meta-learning-with-implicit-gradients-supplemental.zip
# Found title: Adversarial Examples Are Not Bugs, They Are Features
# Found link: https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features
# Found authors: Andrew Ilyas|Shibani Santurkar|Dimitris Tsipras|Logan Engstrom|Brandon Tran|Aleksander Madry
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="8ad06670-4369-4f55-ad2d-cd5d805b1ebb")>
# Found PDF: https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features.pdf
# Downladed file: 8307-adversarial-examples-are-not-bugs-they-are-features.pdf
# Found Supplemental: https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8307-adversarial-examples-are-not-bugs-they-are-features-supplemental.zip
# Downladed file: 8307-adversarial-examples-are-not-bugs-they-are-features-supplemental.zip
# Found title: Social-BiGAT: Multimodal Trajectory Forecasting using Bicycle-GAN and Graph Attention Networks
# Found link: https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks
# Found authors: Vineet Kosaraju|Amir Sadeghian|Roberto Martín-Martín|Ian Reid|Hamid Rezatofighi|Silvio Savarese
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="3459ea9a-d234-4f23-a69c-03b2bdd143cc")>
# Found PDF: https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks.pdf
# Downladed file: 8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks.pdf
# Found Supplemental: https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks-supplemental.zip
# Downladed file: 8308-social-bigat-multimodal-trajectory-forecasting-using-bicycle-gan-and-graph-attention-networks-supplemental.zip
# Found title: FreeAnchor: Learning to Match Anchors for Visual Object Detection
# Found link: https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection
# Found authors: Xiaosong Zhang|Fang Wan|Chang Liu|Rongrong Ji|Qixiang Ye
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="22485cc2-d61c-40af-8445-f03eec6f0b74")>
# Found PDF: https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection.pdf
# Downladed file: 8309-freeanchor-learning-to-match-anchors-for-visual-object-detection.pdf
# Found Supplemental: https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8309-freeanchor-learning-to-match-anchors-for-visual-object-detection-supplemental.zip
# Downladed file: 8309-freeanchor-learning-to-match-anchors-for-visual-object-detection-supplemental.zip
# Found title: Private Hypothesis Selection
# Found link: https://papers.nips.cc/paper/8310-private-hypothesis-selection
# Found authors: Mark Bun|Gautam Kamath|Thomas Steinke|Steven Z. Wu
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="479303cc-78cd-4834-b417-521dc0c404ea")>
# Found PDF: https://papers.nips.cc/paper/8310-private-hypothesis-selection.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8310-private-hypothesis-selection.pdf
# Downladed file: 8310-private-hypothesis-selection.pdf
# Found Supplemental: https://papers.nips.cc/paper/8310-private-hypothesis-selection-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8310-private-hypothesis-selection-supplemental.zip
# Downladed file: 8310-private-hypothesis-selection-supplemental.zip
# Found title: Differentially Private Algorithms for Learning Mixtures of Separated Gaussians
# Found link: https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians
# Found authors: Gautam Kamath|Or Sheffet|Vikrant Singhal|Jonathan Ullman
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="a072759b-3172-4660-b80d-aa547dddebba")>
# Found PDF: https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians.pdf
# Downladed file: 8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians.pdf
# Found Supplemental: https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians-supplemental.zip
# Downladed file: 8311-differentially-private-algorithms-for-learning-mixtures-of-separated-gaussians-supplemental.zip
# Found title: Average-Case Averages: Private Algorithms for Smooth Sensitivity and Mean Estimation
# Found link: https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation
# Found authors: Mark Bun|Thomas Steinke
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="b96c1187-3594-48f6-be0a-4de6b05a1a41")>
# Found PDF: https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation.pdf
# Downladed file: 8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation.pdf
# Found Supplemental: https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation-supplemental.zip
# Downladed file: 8312-average-case-averages-private-algorithms-for-smooth-sensitivity-and-mean-estimation-supplemental.zip
# Found title: Multi-Resolution Weak Supervision for Sequential Data
# Found link: https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data
# Found authors: Paroma Varma|Frederic Sala|Shiori Sagawa|Jason Fries|Daniel Fu|Saelig Khattar|Ashwini Ramamoorthy|Ke Xiao|Kayvon Fatahalian|James Priest|Christopher Ré
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="e104366a-9779-41a2-8444-fdef05b82fc2")>
# Found PDF: https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data.pdf
# Downladed file: 8313-multi-resolution-weak-supervision-for-sequential-data.pdf
# Found Supplemental: https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8313-multi-resolution-weak-supervision-for-sequential-data-supplemental.zip
# Downladed file: 8313-multi-resolution-weak-supervision-for-sequential-data-supplemental.zip
# Found title: DeepUSPS: Deep Robust Unsupervised Saliency Prediction via Self-supervision
# Found link: https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision
# Found authors: Tam Nguyen|Maximilian Dax|Chaithanya Kumar Mummadi|Nhung Ngo|Thi Hoai Phuong Nguyen|Zhongyu Lou|Thomas Brox
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="f932c5d2-6a3a-4aaf-beba-35f6b06e3f68")>
# Found PDF: https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision.pdf
# Downladed file: 8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision.pdf
# Found Supplemental: https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision-supplemental.zip
# Downladed file: 8314-deepusps-deep-robust-unsupervised-saliency-prediction-via-self-supervision-supplemental.zip
# Found title: The Point Where Reality Meets Fantasy: Mixed Adversarial Generators for Image Splice Detection
# Found link: https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection
# Found authors: Vladimir V. Kniaz|Vladimir Knyaz|Fabio Remondino
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="9b0bced4-4329-4449-a3e6-ecc4fc0dc233")>
# Found PDF: https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection.pdf
# Downladed file: 8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection.pdf
# Found Supplemental: https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection-supplemental.zip
# Downladed file: 8315-the-point-where-reality-meets-fantasy-mixed-adversarial-generators-for-image-splice-detection-supplemental.zip
# Found title: You Only Propagate Once: Accelerating Adversarial Training via Maximal Principle
# Found link: https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle
# Found authors: Dinghuai Zhang|Tianyuan Zhang|Yiping Lu|Zhanxing Zhu|Bin Dong
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="e87c3ee9-756d-4436-bf4f-3a2c0207df73")>
# Found PDF: https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle.pdf
# Downladed file: 8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle.pdf
# Found Supplemental: https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle-supplemental.zip
# Downladed file: 8316-you-only-propagate-once-accelerating-adversarial-training-via-maximal-principle-supplemental.zip
# Found title: Imitation Learning from Observations by Minimizing Inverse Dynamics Disagreement
# Found link: https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement
# Found authors: Chao Yang|Xiaojian Ma|Wenbing Huang|Fuchun Sun|Huaping Liu|Junzhou Huang|Chuang Gan
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="2c6ad98e-03c2-4a01-8003-c72d810b892f")>
# Found PDF: https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement.pdf
# Downladed file: 8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement.pdf
# Found Supplemental: https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement-supplemental.zip
# Downladed file: 8317-imitation-learning-from-observations-by-minimizing-inverse-dynamics-disagreement-supplemental.zip
# Found title: Asymptotic Guarantees for Learning Generative Models with the Sliced-Wasserstein Distance
# Found link: https://papers.nips.cc/paper/8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance
# Found authors: Kimia Nadjahi|Alain Durmus|Umut Simsekli|Roland Badeau
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="30dd5c38-9abb-4d31-850e-0f22ec9a3e60")>
# Found PDF: https://papers.nips.cc/paper/8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance.pdf
# Downladed file: 8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance.pdf
# Found Supplemental: https://papers.nips.cc/paper/8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance-supplemental.zip
# Downladed file: 8318-asymptotic-guarantees-for-learning-generative-models-with-the-sliced-wasserstein-distance-supplemental.zip
# Found title: Generalized Sliced Wasserstein Distances
# Found link: https://papers.nips.cc/paper/8319-generalized-sliced-wasserstein-distances
# Found authors: Soheil Kolouri|Kimia Nadjahi|Umut Simsekli|Roland Badeau|Gustavo Rohde
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="c621988a-b995-486b-b971-39134095d53c")>
# Found PDF: https://papers.nips.cc/paper/8319-generalized-sliced-wasserstein-distances.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8319-generalized-sliced-wasserstein-distances.pdf
# Downladed file: 8319-generalized-sliced-wasserstein-distances.pdf
# Found Supplemental: https://papers.nips.cc/paper/8319-generalized-sliced-wasserstein-distances-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8319-generalized-sliced-wasserstein-distances-supplemental.zip
# Downladed file: 8319-generalized-sliced-wasserstein-distances-supplemental.zip
# Found title: First Exit Time Analysis of Stochastic Gradient Descent Under Heavy-Tailed Gradient Noise
# Found link: https://papers.nips.cc/paper/8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise
# Found authors: Thanh Huy Nguyen|Umut Simsekli|Mert Gurbuzbalaban|Gaël RICHARD
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="6092136e-aad0-443f-8613-5363fc1e4e3d")>
# Found PDF: https://papers.nips.cc/paper/8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise.pdf
# Downladed file: 8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise.pdf
# Found Supplemental: https://papers.nips.cc/paper/8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise-supplemental.zip
# Downladed file: 8320-first-exit-time-analysis-of-stochastic-gradient-descent-under-heavy-tailed-gradient-noise-supplemental.zip
# Found title: Blind Super-Resolution Kernel Estimation using an Internal-GAN
# Found link: https://papers.nips.cc/paper/8321-blind-super-resolution-kernel-estimation-using-an-internal-gan
# Found authors: Sefi Bell-Kligler|Assaf Shocher|Michal Irani
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="16b72197-59bd-43c2-9f4b-40ac40faa950")>
# Found PDF: https://papers.nips.cc/paper/8321-blind-super-resolution-kernel-estimation-using-an-internal-gan.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8321-blind-super-resolution-kernel-estimation-using-an-internal-gan.pdf
# Downladed file: 8321-blind-super-resolution-kernel-estimation-using-an-internal-gan.pdf
# Found Supplemental: https://papers.nips.cc/paper/8321-blind-super-resolution-kernel-estimation-using-an-internal-gan-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8321-blind-super-resolution-kernel-estimation-using-an-internal-gan-supplemental.zip
# Downladed file: 8321-blind-super-resolution-kernel-estimation-using-an-internal-gan-supplemental.zip
# Found title: Noise-tolerant fair classification
# Found link: https://papers.nips.cc/paper/8322-noise-tolerant-fair-classification
# Found authors: Alex Lamy|Ziyuan Zhong
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="9908fcef-3f88-4684-9d5a-3c4ab70c5fd2")>
# Found PDF: https://papers.nips.cc/paper/8322-noise-tolerant-fair-classification.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8322-noise-tolerant-fair-classification.pdf
# Downladed file: 8322-noise-tolerant-fair-classification.pdf
# Found Supplemental: https://papers.nips.cc/paper/8322-noise-tolerant-fair-classification-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8322-noise-tolerant-fair-classification-supplemental.zip
# Downladed file: 8322-noise-tolerant-fair-classification-supplemental.zip
# Found title: Generalization in Generative Adversarial Networks: A Novel Perspective from Privacy Protection
# Found link: https://papers.nips.cc/paper/8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection
# Found authors: Bingzhe Wu|Shiwan Zhao|Chaochao Chen|Haoyang Xu|Li Wang|Xiaolu Zhang|Guangyu Sun|Jun Zhou
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="1190eed1-c2dc-42a7-a929-d3b1488e38f6")>
# Found PDF: https://papers.nips.cc/paper/8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection.pdf
# Downladed file: 8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection.pdf
# Found Supplemental: https://papers.nips.cc/paper/8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection-supplemental.zip
# Downladed file: 8323-generalization-in-generative-adversarial-networks-a-novel-perspective-from-privacy-protection-supplemental.zip
# Found title: Joint-task Self-supervised Learning for Temporal Correspondence
# Found link: https://papers.nips.cc/paper/8324-joint-task-self-supervised-learning-for-temporal-correspondence
# Found authors: Xueting Li|Sifei Liu|Shalini De Mello|Xiaolong Wang|Jan Kautz|Ming-Hsuan Yang
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="805fdd16-905a-4e24-9ac6-383ca3a59153")>
# Found PDF: https://papers.nips.cc/paper/8324-joint-task-self-supervised-learning-for-temporal-correspondence.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8324-joint-task-self-supervised-learning-for-temporal-correspondence.pdf
# Downladed file: 8324-joint-task-self-supervised-learning-for-temporal-correspondence.pdf
# Found Supplemental: https://papers.nips.cc/paper/8324-joint-task-self-supervised-learning-for-temporal-correspondence-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8324-joint-task-self-supervised-learning-for-temporal-correspondence-supplemental.zip
# Downladed file: 8324-joint-task-self-supervised-learning-for-temporal-correspondence-supplemental.zip
# Found title: Provable Gradient Variance Guarantees for Black-Box Variational Inference
# Found link: https://papers.nips.cc/paper/8325-provable-gradient-variance-guarantees-for-black-box-variational-inference
# Found authors: Justin Domke
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="47b234f3-cb27-4b14-9448-ba6ffcd20120")>
# Found PDF: https://papers.nips.cc/paper/8325-provable-gradient-variance-guarantees-for-black-box-variational-inference.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8325-provable-gradient-variance-guarantees-for-black-box-variational-inference.pdf
# Downladed file: 8325-provable-gradient-variance-guarantees-for-black-box-variational-inference.pdf
# Found Supplemental: https://papers.nips.cc/paper/8325-provable-gradient-variance-guarantees-for-black-box-variational-inference-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8325-provable-gradient-variance-guarantees-for-black-box-variational-inference-supplemental.zip
# Downladed file: 8325-provable-gradient-variance-guarantees-for-black-box-variational-inference-supplemental.zip
# Found title: Divide and Couple: Using Monte Carlo Variational Objectives for Posterior Approximation
# Found link: https://papers.nips.cc/paper/8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation
# Found authors: Justin Domke|Daniel R. Sheldon
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="85e21df7-0292-4b20-9a22-7dd5cc29f9eb")>
# Found PDF: https://papers.nips.cc/paper/8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation.pdf
# Downladed file: 8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation.pdf
# Found Supplemental: https://papers.nips.cc/paper/8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation-supplemental.zip
# Downladed file: 8326-divide-and-couple-using-monte-carlo-variational-objectives-for-posterior-approximation-supplemental.zip
# Found title: Experience Replay for Continual Learning
# Found link: https://papers.nips.cc/paper/8327-experience-replay-for-continual-learning
# Found authors: David Rolnick|Arun Ahuja|Jonathan Schwarz|Timothy Lillicrap|Gregory Wayne
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="6b19b243-3d55-4cc3-a866-34ffa270505b")>
# Found PDF: https://papers.nips.cc/paper/8327-experience-replay-for-continual-learning.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8327-experience-replay-for-continual-learning.pdf
# Downladed file: 8327-experience-replay-for-continual-learning.pdf
# Found Supplemental: https://papers.nips.cc/paper/8327-experience-replay-for-continual-learning-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8327-experience-replay-for-continual-learning-supplemental.zip
# Downladed file: 8327-experience-replay-for-continual-learning-supplemental.zip
# Found title: Deep ReLU Networks Have Surprisingly Few Activation Patterns
# Found link: https://papers.nips.cc/paper/8328-deep-relu-networks-have-surprisingly-few-activation-patterns
# Found authors: Boris Hanin|David Rolnick
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="cf7645a4-6ed2-44d0-be2e-af5934e4c651")>
# Found PDF: https://papers.nips.cc/paper/8328-deep-relu-networks-have-surprisingly-few-activation-patterns.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8328-deep-relu-networks-have-surprisingly-few-activation-patterns.pdf
# Downladed file: 8328-deep-relu-networks-have-surprisingly-few-activation-patterns.pdf
# Found Supplemental: https://papers.nips.cc/paper/8328-deep-relu-networks-have-surprisingly-few-activation-patterns-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8328-deep-relu-networks-have-surprisingly-few-activation-patterns-supplemental.zip
# Downladed file: 8328-deep-relu-networks-have-surprisingly-few-activation-patterns-supplemental.zip
# Found title: Chasing Ghosts: Instruction Following as Bayesian State Tracking
# Found link: https://papers.nips.cc/paper/8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking
# Found authors: Peter Anderson|Ayush Shrivastava|Devi Parikh|Dhruv Batra|Stefan Lee
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="e959b076-e6a3-4776-8586-1f70bcf04feb")>
# Found PDF: https://papers.nips.cc/paper/8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking.pdf
# Downladed file: 8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking.pdf
# Found Supplemental: https://papers.nips.cc/paper/8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking-supplemental.zip
# Downladed file: 8329-chasing-ghosts-instruction-following-as-bayesian-state-tracking-supplemental.zip
# Found title: Block Coordinate Regularization by Denoising
# Found link: https://papers.nips.cc/paper/8330-block-coordinate-regularization-by-denoising
# Found authors: Yu Sun|Jiaming Liu|Ulugbek Kamilov
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="9bf57457-8240-454a-8897-a5164cfef228")>
# Found PDF: https://papers.nips.cc/paper/8330-block-coordinate-regularization-by-denoising.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8330-block-coordinate-regularization-by-denoising.pdf
# Downladed file: 8330-block-coordinate-regularization-by-denoising.pdf
# Found Supplemental: https://papers.nips.cc/paper/8330-block-coordinate-regularization-by-denoising-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8330-block-coordinate-regularization-by-denoising-supplemental.zip
# Downladed file: 8330-block-coordinate-regularization-by-denoising-supplemental.zip
# Found title: Reducing Noise in GAN Training with Variance Reduced Extragradient
# Found link: https://papers.nips.cc/paper/8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient
# Found authors: Tatjana Chavdarova|Gauthier Gidel|François Fleuret|Simon Lacoste-Julien
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="5c60f3db-58e1-4cda-9178-3806ed9df8dd")>
# Found PDF: https://papers.nips.cc/paper/8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient.pdf
# Downladed file: 8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient.pdf
# Found Supplemental: https://papers.nips.cc/paper/8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient-supplemental.zip
# Downladed file: 8331-reducing-noise-in-gan-training-with-variance-reduced-extragradient-supplemental.zip
# Found title: Learning Erdos-Renyi Random Graphs via Edge Detecting Queries
# Found link: https://papers.nips.cc/paper/8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries
# Found authors: Zihan Li|Matthias Fresacher|Jonathan Scarlett
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="a91e6d62-c5d7-4c41-838d-24211b7c18ec")>
# Found PDF: https://papers.nips.cc/paper/8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries.pdf
# Downladed file: 8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries.pdf
# Found Supplemental: https://papers.nips.cc/paper/8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries-supplemental.zip
# Downladed file: 8332-learning-erdos-renyi-random-graphs-via-edge-detecting-queries-supplemental.zip
# Found title: A Primal-Dual link between GANs and Autoencoders
# Found link: https://papers.nips.cc/paper/8333-a-primal-dual-link-between-gans-and-autoencoders
# Found authors: Hisham Husain|Richard Nock|Robert C. Williamson
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="ca67afdb-34bc-47b6-b970-fa643cce39d8")>
# Found PDF: https://papers.nips.cc/paper/8333-a-primal-dual-link-between-gans-and-autoencoders.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8333-a-primal-dual-link-between-gans-and-autoencoders.pdf
# Downladed file: 8333-a-primal-dual-link-between-gans-and-autoencoders.pdf
# Found Supplemental: https://papers.nips.cc/paper/8333-a-primal-dual-link-between-gans-and-autoencoders-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/8333-a-primal-dual-link-between-gans-and-autoencoders-supplemental.zip
# Downladed file: 8333-a-primal-dual-link-between-gans-and-autoencoders-supplemental.zip
# Found title: muSSP: Efficient Min-cost Flow Algorithm for Multi-object Tracking
# Found link: https://papers.nips.cc/paper/8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking
# Found authors: Congchao Wang|Yizhi Wang|Yinxue Wang|Chiung-Ting Wu|Guoqiang Yu
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="0a99ed03-fbc5-48a5-9347-b182d1bf57a0")>
# Found PDF: https://papers.nips.cc/paper/8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking.pdf
# Downladed file: 8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking.pdf
# Found Supplemental: https://papers.nips.cc/paper/8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking-supplemental.zip
# Downladed file: 8334-mussp-efficient-min-cost-flow-algorithm-for-multi-object-tracking-supplemental.zip
# Found title: Category Anchor-Guided Unsupervised Domain Adaptation for Semantic Segmentation
# Found link: https://papers.nips.cc/paper/8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation
# Found authors: Qiming ZHANG|Jing Zhang|Wei Liu|Dacheng Tao
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="35ca5088-961b-490d-b375-b813553287c3")>
# Found PDF: https://papers.nips.cc/paper/8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation.pdf
# Downladed file: 8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation.pdf
# Found Supplemental: https://papers.nips.cc/paper/8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation-supplemental.zip
# Downladed file: 8335-category-anchor-guided-unsupervised-domain-adaptation-for-semantic-segmentation-supplemental.zip
# Found title: Invert to Learn to Invert
# Found link: https://papers.nips.cc/paper/8336-invert-to-learn-to-invert
# Found authors: Patrick Putzky|Max Welling
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="25eb10dd-9cc0-4b4f-a91a-5e8ee99773cb")>
# Found PDF: https://papers.nips.cc/paper/8336-invert-to-learn-to-invert.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/8336-invert-to-learn-to-invert.pdf
# Downladed file: 8336-invert-to-learn-to-invert.pdf
# ...
# Downladed file: 9710-pidforest-anomaly-detection-via-partial-identification.pdf
# Found Supplemental: https://papers.nips.cc/paper/9710-pidforest-anomaly-detection-via-partial-identification-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9710-pidforest-anomaly-detection-via-partial-identification-supplemental.zip
# Downladed file: 9710-pidforest-anomaly-detection-via-partial-identification-supplemental.zip
# Found title: Generative Models for Graph-Based Protein Design
# Found link: https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design
# Found authors: John Ingraham|Vikas Garg|Regina Barzilay|Tommi Jaakkola
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="93d881f3-2cdc-4ddf-a07b-d122dd9bcd29")>
# Found PDF: https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design.pdf
# Downladed file: 9711-generative-models-for-graph-based-protein-design.pdf
# Found Supplemental: https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9711-generative-models-for-graph-based-protein-design-supplemental.zip
# Downladed file: 9711-generative-models-for-graph-based-protein-design-supplemental.zip
# Found title: The Geometry of Deep Networks: Power Diagram Subdivision
# Found link: https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision
# Found authors: Randall Balestriero|Romain Cosentino|Behnaam Aazhang|Richard Baraniuk
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="6e46fcc6-f45d-4747-a66b-9542f968ba26")>
# Found PDF: https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision.pdf
# Downladed file: 9712-the-geometry-of-deep-networks-power-diagram-subdivision.pdf
# Found Supplemental: https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9712-the-geometry-of-deep-networks-power-diagram-subdivision-supplemental.zip
# Downladed file: 9712-the-geometry-of-deep-networks-power-diagram-subdivision-supplemental.zip
# Found title: Approximate Feature Collisions in Neural Nets
# Found link: https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets
# Found authors: Ke Li|Tianhao Zhang|Jitendra Malik
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="215c7d54-97fd-4133-ac69-2a1237407fb3")>
# Found PDF: https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets.pdf
# Downladed file: 9713-approximate-feature-collisions-in-neural-nets.pdf
# Found Supplemental: https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9713-approximate-feature-collisions-in-neural-nets-supplemental.zip
# Downladed file: 9713-approximate-feature-collisions-in-neural-nets-supplemental.zip
# Found title: Ease-of-Teaching and Language Structure from Emergent Communication
# Found link: https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication
# Found authors: Fushan Li|Michael Bowling
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="454e910f-4a95-4bf7-aff7-13c3ad38fd0d")>
# Found PDF: https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication.pdf
# Downladed file: 9714-ease-of-teaching-and-language-structure-from-emergent-communication.pdf
# Found Supplemental: https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication-supplemental.zip
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9714-ease-of-teaching-and-language-structure-from-emergent-communication-supplemental.zip
# Downladed file: 9714-ease-of-teaching-and-language-structure-from-emergent-communication-supplemental.zip
# Found title: Generalization in multitask deep neural classifiers: a statistical physics approach
# Found link: https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach
# Found authors: Anthony Ndirango|Tyler Lee
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="a0edde95-17f8-49fd-9c70-cface52bb8e1")>
# Found PDF: https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach.pdf
# Downladed file: 9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach.pdf
# Found Supplemental: https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach-supplemental.zip
# Downladed file: 9715-generalization-in-multitask-deep-neural-classifiers-a-statistical-physics-approach-supplemental.zip
# Found title: Optimistic Distributionally Robust Optimization for Nonparametric Likelihood Approximation
# Found link: https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation
# Found authors: Viet Anh Nguyen|Soroosh Shafieezadeh Abadeh|Man-Chung Yue|Daniel Kuhn|Wolfram Wiesemann
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="690806d2-88ea-4187-9b8a-64064c746d84")>
# Found PDF: https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation.pdf
# Downladed file: 9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation.pdf
# Found Supplemental: https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation-supplemental.zip
# Downladed file: 9716-optimistic-distributionally-robust-optimization-for-nonparametric-likelihood-approximation-supplemental.zip
# Found title: On Relating Explanations and Adversarial Examples
# Found link: https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples
# Found authors: Alexey Ignatiev|Nina Narodytska|Joao Marques-Silva
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="5b8ac8d4-1999-444a-ad0c-326854dceeac")>
# Found PDF: https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples.pdf
# Downladed file: 9717-on-relating-explanations-and-adversarial-examples.pdf
# Found Supplemental: https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9717-on-relating-explanations-and-adversarial-examples-supplemental.zip
# Downladed file: 9717-on-relating-explanations-and-adversarial-examples-supplemental.zip
# Found title: On the equivalence between graph isomorphism testing and function approximation with GNNs
# Found link: https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns
# Found authors: Zhengdao Chen|Soledad Villar|Lei Chen|Joan Bruna
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="18d38cf6-2110-4b6d-a836-2bb38e9193b0")>
# Found PDF: https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns.pdf
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns.pdf
# Downladed file: 9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns.pdf
# Found Supplemental: https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns-supplemental.zip
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns-supplemental.zip
# Downladed file: 9718-on-the-equivalence-between-graph-isomorphism-testing-and-function-approximation-with-gnns-supplemental.zip
# Found title: Surround Modulation: A Bio-inspired Connectivity Structure for Convolutional Neural Networks
# Found link: https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks
# Found authors: Hosein Hasani|Mahdieh Soleymani|Hamid Aghajan
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="6a5dfecc-8849-4b54-beba-ec8870c93ae7")>
# Found PDF: https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks.pdf
# Waiting 3 seconds to retrieve https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks.pdf
# Downladed file: 9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks.pdf
# Found Supplemental: https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks-supplemental.zip
# Downladed file: 9719-surround-modulation-a-bio-inspired-connectivity-structure-for-convolutional-neural-networks-supplemental.zip
# Found title: Self-attention with Functional Time Representation Learning
# Found link: https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning
# Found authors: Da Xu|Chuanwei Ruan|Evren Korpeoglu|Sushant Kumar|Kannan Achan
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="05fad442-d90f-4f4e-8f6c-23e89a22e927")>
# Found PDF: https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning.pdf
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning.pdf
# Downladed file: 9720-self-attention-with-functional-time-representation-learning.pdf
# Found Supplemental: https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9720-self-attention-with-functional-time-representation-learning-supplemental.zip
# Downladed file: 9720-self-attention-with-functional-time-representation-learning-supplemental.zip
# Found title: Re-randomized Densification for One Permutation Hashing and Bin-wise Consistent Weighted Sampling
# Found link: https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling
# Found authors: Ping Li|Xiaoyun Li|Cun-Hui Zhang
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="55805f19-edbb-4477-9fdd-3a7f1f9d6693")>
# Found PDF: https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling.pdf
# Downladed file: 9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling.pdf
# Found Supplemental: https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling-supplemental.zip
# Downladed file: 9721-re-randomized-densification-for-one-permutation-hashing-and-bin-wise-consistent-weighted-sampling-supplemental.zip
# Found title: Enabling hyperparameter optimization in sequential autoencoders for spiking neural data
# Found link: https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data
# Found authors: Mohammad Reza Keshtkaran|Chethan Pandarinath
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="9f311652-6295-40a3-b5d0-749ed63314df")>
# Found PDF: https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data.pdf
# Downladed file: 9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data.pdf
# Found Supplemental: https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data-supplemental.zip
# Waiting 2 seconds to retrieve https://papers.nips.cc/paper/9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data-supplemental.zip
# Downladed file: 9722-enabling-hyperparameter-optimization-in-sequential-autoencoders-for-spiking-neural-data-supplemental.zip
# Found title: Mixtape: Breaking the Softmax Bottleneck Efficiently
# Found link: https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently
# Found authors: Zhilin Yang|Thang Luong|Russ R. Salakhutdinov|Quoc V. Le
# Found abstract: <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="787e38a3-34d8-4360-a162-3d8a18757d62", element="c6305ed1-ddcd-4f45-8c05-330e6f1de899")>
# Found PDF: https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently.pdf
# Waiting 5 seconds to retrieve https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently.pdf
# Downladed file: 9723-mixtape-breaking-the-softmax-bottleneck-efficiently.pdf
# Found Supplemental: https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently-supplemental.zip
# Waiting 4 seconds to retrieve https://papers.nips.cc/paper/9723-mixtape-breaking-the-softmax-bottleneck-efficiently-supplemental.zip
# Downladed file: 9723-mixtape-breaking-the-softmax-bottleneck-efficiently-supplemental.zip

# %%
home_page_browser.quit()
print('Finished finding all available documents on the presentation pages!')
print('Total presentations processed:', num_presentations)
print('Total documents downloaded:', num_documents)
# Out:
# Finished finding all available documents on the presentation pages!
# Total presentations processed: 1427
# Total documents downloaded: 2854

# %%
if (notifyStatus): email_notify("Phase 2 Perform the Scraping and Processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 4:06:10.293176
